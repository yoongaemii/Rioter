# %% [markdown]
# # Riot API Call Functions
# API key: RGAPI-017be2b5-f243-44a5-b78b-40e6ec73a3ef
# Documentation: https://developer.riotgames.com/api-methods/

# %% [markdown]
# # Dynamic Data

# %%
import requests
import json
from pprint import pprint

api_key = "RGAPI-017be2b5-f243-44a5-b78b-40e6ec73a3ef"

# 접근할 수 있는 summoner_name => account_id로(공식 문서의 encrypted summoner id)
def get_account_id(summoner_name):
    api_data = requests.get("https://kr.api.riotgames.com/lol/summoner/v4/summoners/by-name/{0}?api_key={1}".format(summoner_name, api_key))
    json_data = json.loads(api_data.content.decode("utf-8"))
    return json_data['accountId']

# account_id로 최근 100개의 game_id를 list로 반환
def get_match_history(account_id):
    api_data = requests.get("https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/{0}?api_key={1}".format(account_id, api_key))
    json_data = json.loads(api_data.content.decode("utf-8")) 
    # matches라는 key 안에 최대 최근 100개의 match 정보
    # total Games를 알 수 있고 startIndex, endIndex를 조절해서 그 이전 데이터를 따로 불러올 수 있다
    game_id_list = [match['gameId'] for match in json_data['matches']]
    return game_id_list


def get_game_detail(game_id):
    api_data = requests.get("https://kr.api.riotgames.com//lol/match/v4/matches/{0}?api_key={1}".format(game_id, api_key))
    json_data = json.loads(api_data.content.decode("utf-8"))
    return json_data

# %%
game_id = 3309773060
api_data = requests.get("https://kr.api.riotgames.com//lol/match/v4/timelines/by-match/{0}?api_key={1}".format(game_id, api_key))
json_data = json.loads(api_data.content.decode("utf-8"))
pprint(json_data)
# Out:
# {'frameInterval': 60000,
#  'frames': [{'events': [],
#              'participantFrames': {'1': {'currentGold': 500,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 0,
#                                          'level': 1,
#                                          'minionsKilled': 0,
#                                          'participantId': 1,
#                                          'position': {'x': 311, 'y': 649},
#                                          'teamScore': 0,
#                                          'totalGold': 500,
#                                          'xp': 0},
#                                    '10': {'currentGold': 500,
#                                           'dominionScore': 0,
#                                           'jungleMinionsKilled': 0,
#                                           'level': 1,
#                                           'minionsKilled': 0,
#                                           'participantId': 10,
#                                           'position': {'x': 14486, 'y': 14511},
#                                           'teamScore': 0,
#                                           'totalGold': 500,
#                                           'xp': 0},
#                                    '2': {'currentGold': 500,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 0,
#                                          'level': 1,
#                                          'minionsKilled': 0,
#                                          'participantId': 2,
#                                          'position': {'x': 351, 'y': 293},
#                                          'teamScore': 0,
#                                          'totalGold': 500,
#                                          'xp': 0},
#                                    '3': {'currentGold': 500,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 0,
#                                          'level': 1,
#                                          'minionsKilled': 0,
#                                          'participantId': 3,
#                                          'position': {'x': 222, 'y': 471},
#                                          'teamScore': 0,
#                                          'totalGold': 500,
#                                          'xp': 0},
#                                    '4': {'currentGold': 500,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 0,
#                                          'level': 1,
#                                          'minionsKilled': 0,
#                                          'participantId': 4,
#                                          'position': {'x': 561, 'y': 581},
#                                          'teamScore': 0,
#                                          'totalGold': 500,
#                                          'xp': 0},
#                                    '5': {'currentGold': 500,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 0,
#                                          'level': 1,
#                                          'minionsKilled': 0,
#                                          'participantId': 5,
#                                          'position': {'x': 561, 'y': 361},
#                                          'teamScore': 0,
#                                          'totalGold': 500,
#                                          'xp': 0},
#                                    '6': {'currentGold': 500,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 0,
#                                          'level': 1,
#                                          'minionsKilled': 0,
#                                          'participantId': 6,
#                                          'position': {'x': 14148, 'y': 14401},
#                                          'teamScore': 0,
#                                          'totalGold': 500,
#                                          'xp': 0},
#                                    '7': {'currentGold': 500,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 0,
#                                          'level': 1,
#                                          'minionsKilled': 0,
#                                          'participantId': 7,
#                                          'position': {'x': 14277, 'y': 14223},
#                                          'teamScore': 0,
#                                          'totalGold': 500,
#                                          'xp': 0},
#                                    '8': {'currentGold': 500,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 0,
#                                          'level': 1,
#                                          'minionsKilled': 0,
#                                          'participantId': 8,
#                                          'position': {'x': 14486, 'y': 14291},
#                                          'teamScore': 0,
#                                          'totalGold': 500,
#                                          'xp': 0},
#                                    '9': {'currentGold': 500,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 0,
#                                          'level': 1,
#                                          'minionsKilled': 0,
#                                          'participantId': 9,
#                                          'position': {'x': 14237, 'y': 14579},
#                                          'teamScore': 0,
#                                          'totalGold': 500,
#                                          'xp': 0}},
#              'timestamp': 0},
#             {'events': [{'levelUpType': 'NORMAL',
#                          'participantId': 3,
#                          'skillSlot': 1,
#                          'timestamp': 5769,
#                          'type': 'SKILL_LEVEL_UP'},
#                         {'itemId': 1055,
#                          'participantId': 3,
#                          'timestamp': 7749,
#                          'type': 'ITEM_PURCHASED'},
#                         {'itemId': 2033,
#                          'participantId': 4,
#                          'timestamp': 8013,
#                          'type': 'ITEM_PURCHASED'},
#                         {'itemId': 2003,
#                          'participantId': 3,
#                          'timestamp': 8079,
#                          'type': 'ITEM_PURCHASED'},
#                         {'itemId': 3340,
#                          'participantId': 3,
#                          'timestamp': 8574,
#                          'type': 'ITEM_PURCHASED'},
#                         {'levelUpType': 'NORMAL',
#                          'participantId': 5,
#                          'skillSlot': 1,
#                          'timestamp': 8673,
#                          'type': 'SKILL_LEVEL_UP'},
#                         {'itemId': 3340,
#                          'participantId': 4,
#                          'timestamp': 9201,
#                          'type': 'ITEM_PURCHASED'},
#                         {'itemId': 2033,
#                          'participantId': 10,
#                          'timestamp': 10554,
#                          'type': 'ITEM_PURCHASED'},
#                         {'itemId': 3302,
#                          'participantId': 9,
#                          'timestamp': 12204,
#                          'type': 'ITEM_PURCHASED'},
#                         {'itemId': 2003,
#                          'participantId': 9,
#                          'timestamp': 12501,
#                          'type': 'ITEM_PURCHASED'},
#                         {'itemId': 2003,
#                          'participantId': 9,
#                          'timestamp': 12666,
#                          'type': 'ITEM_PURCHASED'},
#                         {'itemId': 3340,
#                          'participantId': 9,
#                          'timestamp': 13095,
#                          'type': 'ITEM_PURCHASED'},
#                         {'levelUpType': 'NORMAL',
#                          'participantId': 10,
#                          'skillSlot': 3,
#                          'timestamp': 13590,
#                          'type': 'SKILL_LEVEL_UP'},
#                         {'itemId': 2003,
#                          'participantId': 6,
#                          'timestamp': 15966,
#                          'type': 'ITEM_PURCHASED'},
#                         {'itemId': 1055,
#                          'participantId': 6,
#                          'timestamp': 16197,
#                          'type': 'ITEM_PURCHASED'},
#                         {'itemId': 3340,
#                          'participantId': 6,
#                          'timestamp': 16725,
#                          'type': 'ITEM_PURCHASED'},
#                         {'itemId': 2033,
#                          'participantId': 7,
#                          'timestamp': 18507,
#                          'type': 'ITEM_PURCHASED'},
#                         {'itemId': 1039,
#                          'participantId': 5,
#                          'timestamp': 18573,
#                          'type': 'ITEM_PURCHASED'},
#                         {'itemId': 1006,
#                          'participantId': 5,
#                          'timestamp': 19233,
#                          'type': 'ITEM_PURCHASED'},
#                         {'itemId': 3340,
#                          'participantId': 7,
#                          'timestamp': 19497,
#                          'type': 'ITEM_PURCHASED'},
#                         {'itemId': 3340,
#                          'participantId': 5,
#                          'timestamp': 19761,
#                          'type': 'ITEM_PURCHASED'},
#                         {'levelUpType': 'NORMAL',
#                          'participantId': 6,
#                          'skillSlot': 1,
#                          'timestamp': 21114,
#                          'type': 'SKILL_LEVEL_UP'},
#                         {'levelUpType': 'NORMAL',
#                          'participantId': 8,
#                          'skillSlot': 1,
#                          'timestamp': 22467,
#                          'type': 'SKILL_LEVEL_UP'},
#                         {'itemId': 3301,
#                          'participantId': 1,
#                          'timestamp': 22764,
#                          'type': 'ITEM_PURCHASED'},
#                         {'itemId': 3340,
#                          'participantId': 1,
#                          'timestamp': 23754,
#                          'type': 'ITEM_PURCHASED'},
#                         {'itemId': 1039,
#                          'participantId': 8,
#                          'timestamp': 24183,
#                          'type': 'ITEM_PURCHASED'},
#                         {'itemId': 2031,
#                          'participantId': 8,
#                          'timestamp': 24546,
#                          'type': 'ITEM_PURCHASED'},
#                         {'itemId': 3340,
#                          'participantId': 8,
#                          'timestamp': 24975,
#                          'type': 'ITEM_PURCHASED'},
#                         {'itemId': 2003,
#                          'participantId': 1,
#                          'timestamp': 25305,
#                          'type': 'ITEM_PURCHASED'},
#                         {'itemId': 2003,
#                          'participantId': 1,
#                          'timestamp': 25536,
#                          'type': 'ITEM_PURCHASED'},
#                         {'itemId': 1055,
#                          'participantId': 2,
#                          'timestamp': 39264,
#                          'type': 'ITEM_PURCHASED'},
#                         {'itemId': 2003,
#                          'participantId': 2,
#                          'timestamp': 39660,
#                          'type': 'ITEM_PURCHASED'},
#                         {'itemId': 3340,
#                          'participantId': 2,
#                          'timestamp': 40122,
#                          'type': 'ITEM_PURCHASED'},
#                         {'levelUpType': 'NORMAL',
#                          'participantId': 7,
#                          'skillSlot': 1,
#                          'timestamp': 52728,
#                          'type': 'SKILL_LEVEL_UP'}],
#              'participantFrames': {'1': {'currentGold': 0,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 0,
#                                          'level': 1,
#                                          'minionsKilled': 0,
#                                          'participantId': 1,
#                                          'position': {'x': 11236, 'y': 3424},
#                                          'teamScore': 0,
#                                          'totalGold': 500,
#                                          'xp': 0},
#                                    '10': {'currentGold': 0,
#                                           'dominionScore': 0,
#                                           'jungleMinionsKilled': 0,
#                                           'level': 1,
#                                           'minionsKilled': 0,
#                                           'participantId': 10,
#                                           'position': {'x': 4344, 'y': 14010},
#                                           'teamScore': 0,
#                                           'totalGold': 500,
#                                           'xp': 0},
#                                    '2': {'currentGold': 0,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 0,
#                                          'level': 1,
#                                          'minionsKilled': 0,
#                                          'participantId': 2,
#                                          'position': {'x': 5800, 'y': 6018},
#                                          'teamScore': 0,
#                                          'totalGold': 500,
#                                          'xp': 0},
#                                    '3': {'currentGold': 0,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 0,
#                                          'level': 1,
#                                          'minionsKilled': 0,
#                                          'participantId': 3,
#                                          'position': {'x': 10949, 'y': 3368},
#                                          'teamScore': 0,
#                                          'totalGold': 500,
#                                          'xp': 0},
#                                    '4': {'currentGold': 0,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 0,
#                                          'level': 1,
#                                          'minionsKilled': 0,
#                                          'participantId': 4,
#                                          'position': {'x': 3303, 'y': 7848},
#                                          'teamScore': 0,
#                                          'totalGold': 500,
#                                          'xp': 0},
#                                    '5': {'currentGold': 0,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 0,
#                                          'level': 1,
#                                          'minionsKilled': 0,
#                                          'participantId': 5,
#                                          'position': {'x': 3429, 'y': 7722},
#                                          'teamScore': 0,
#                                          'totalGold': 500,
#                                          'xp': 0},
#                                    '6': {'currentGold': 0,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 0,
#                                          'level': 1,
#                                          'minionsKilled': 0,
#                                          'participantId': 6,
#                                          'position': {'x': 10967, 'y': 5528},
#                                          'teamScore': 0,
#                                          'totalGold': 500,
#                                          'xp': 0},
#                                    '7': {'currentGold': 0,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 0,
#                                          'level': 1,
#                                          'minionsKilled': 0,
#                                          'participantId': 7,
#                                          'position': {'x': 9867, 'y': 6420},
#                                          'teamScore': 0,
#                                          'totalGold': 500,
#                                          'xp': 0},
#                                    '8': {'currentGold': 0,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 0,
#                                          'level': 1,
#                                          'minionsKilled': 0,
#                                          'participantId': 8,
#                                          'position': {'x': 9476, 'y': 5594},
#                                          'teamScore': 0,
#                                          'totalGold': 500,
#                                          'xp': 0},
#                                    '9': {'currentGold': 0,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 0,
#                                          'level': 1,
#                                          'minionsKilled': 0,
#                                          'participantId': 9,
#                                          'position': {'x': 9451, 'y': 5699},
#                                          'teamScore': 0,
#                                          'totalGold': 500,
#                                          'xp': 0}},
#              'timestamp': 60022},
#             {'events': [{'levelUpType': 'NORMAL',
#                          'participantId': 1,
#                          'skillSlot': 1,
#                          'timestamp': 63723,
#                          'type': 'SKILL_LEVEL_UP'},
#                         {'levelUpType': 'NORMAL',
#                          'participantId': 4,
#                          'skillSlot': 3,
#                          'timestamp': 77715,
#                          'type': 'SKILL_LEVEL_UP'},
#                         {'levelUpType': 'NORMAL',
#                          'participantId': 9,
#                          'skillSlot': 2,
#                          'timestamp': 93886,
#                          'type': 'SKILL_LEVEL_UP'},
#                         {'levelUpType': 'NORMAL',
#                          'participantId': 2,
#                          'skillSlot': 1,
#                          'timestamp': 99166,
#                          'type': 'SKILL_LEVEL_UP'},
#                         {'levelUpType': 'NORMAL',
#                          'participantId': 5,
#                          'skillSlot': 3,
#                          'timestamp': 103918,
#                          'type': 'SKILL_LEVEL_UP'},
#                         {'levelUpType': 'NORMAL',
#                          'participantId': 8,
#                          'skillSlot': 2,
#                          'timestamp': 105073,
#                          'type': 'SKILL_LEVEL_UP'}],
#              'participantFrames': {'1': {'currentGold': 47,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 0,
#                                          'level': 1,
#                                          'minionsKilled': 0,
#                                          'participantId': 1,
#                                          'position': {'x': 11810, 'y': 2258},
#                                          'teamScore': 0,
#                                          'totalGold': 547,
#                                          'xp': 115},
#                                    '10': {'currentGold': 111,
#                                           'dominionScore': 0,
#                                           'jungleMinionsKilled': 0,
#                                           'level': 1,
#                                           'minionsKilled': 5,
#                                           'participantId': 10,
#                                           'position': {'x': 2537, 'y': 12500},
#                                           'teamScore': 0,
#                                           'totalGold': 611,
#                                           'xp': 235},
#                                    '2': {'currentGold': 83,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 0,
#                                          'level': 1,
#                                          'minionsKilled': 3,
#                                          'participantId': 2,
#                                          'position': {'x': 6712, 'y': 7275},
#                                          'teamScore': 0,
#                                          'totalGold': 583,
#                                          'xp': 176},
#                                    '3': {'currentGold': 20,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 0,
#                                          'level': 1,
#                                          'minionsKilled': 0,
#                                          'participantId': 3,
#                                          'position': {'x': 12047, 'y': 1825},
#                                          'teamScore': 0,
#                                          'totalGold': 520,
#                                          'xp': 115},
#                                    '4': {'currentGold': 62,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 0,
#                                          'level': 1,
#                                          'minionsKilled': 2,
#                                          'participantId': 4,
#                                          'position': {'x': 1774, 'y': 11815},
#                                          'teamScore': 0,
#                                          'totalGold': 562,
#                                          'xp': 176},
#                                    '5': {'currentGold': 152,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 6,
#                                          'level': 2,
#                                          'minionsKilled': 0,
#                                          'participantId': 5,
#                                          'position': {'x': 3601, 'y': 6345},
#                                          'teamScore': 0,
#                                          'totalGold': 652,
#                                          'xp': 335},
#                                    '6': {'currentGold': 62,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 0,
#                                          'level': 1,
#                                          'minionsKilled': 2,
#                                          'participantId': 6,
#                                          'position': {'x': 12731, 'y': 2741},
#                                          'teamScore': 0,
#                                          'totalGold': 562,
#                                          'xp': 115},
#                                    '7': {'currentGold': 125,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 0,
#                                          'level': 1,
#                                          'minionsKilled': 6,
#                                          'participantId': 7,
#                                          'position': {'x': 7894, 'y': 7637},
#                                          'teamScore': 0,
#                                          'totalGold': 625,
#                                          'xp': 264},
#                                    '8': {'currentGold': 120,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 4,
#                                          'level': 2,
#                                          'minionsKilled': 0,
#                                          'participantId': 8,
#                                          'position': {'x': 12388, 'y': 6433},
#                                          'teamScore': 0,
#                                          'totalGold': 620,
#                                          'xp': 285},
#                                    '9': {'currentGold': 21,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 0,
#                                          'level': 1,
#                                          'minionsKilled': 0,
#                                          'participantId': 9,
#                                          'position': {'x': 12880, 'y': 2320},
#                                          'teamScore': 0,
#                                          'totalGold': 521,
#                                          'xp': 115}},
#              'timestamp': 120023},
#             {'events': [{'levelUpType': 'NORMAL',
#                          'participantId': 7,
#                          'skillSlot': 3,
#                          'timestamp': 125039,
#                          'type': 'SKILL_LEVEL_UP'},
#                         {'itemId': 2003,
#                          'participantId': 9,
#                          'timestamp': 130385,
#                          'type': 'ITEM_DESTROYED'},
#                         {'creatorId': 5,
#                          'timestamp': 132365,
#                          'type': 'WARD_PLACED',
#                          'wardType': 'YELLOW_TRINKET'},
#                         {'levelUpType': 'NORMAL',
#                          'participantId': 10,
#                          'skillSlot': 1,
#                          'timestamp': 132398,
#                          'type': 'SKILL_LEVEL_UP'},
#                         {'creatorId': 9,
#                          'timestamp': 144543,
#                          'type': 'WARD_PLACED',
#                          'wardType': 'YELLOW_TRINKET'},
#                         {'levelUpType': 'NORMAL',
#                          'participantId': 2,
#                          'skillSlot': 3,
#                          'timestamp': 144543,
#                          'type': 'SKILL_LEVEL_UP'},
#                         {'creatorId': 8,
#                          'timestamp': 146655,
#                          'type': 'WARD_PLACED',
#                          'wardType': 'YELLOW_TRINKET'},
#                         {'levelUpType': 'NORMAL',
#                          'participantId': 9,
#                          'skillSlot': 1,
#                          'timestamp': 147480,
#                          'type': 'SKILL_LEVEL_UP'},
#                         {'levelUpType': 'NORMAL',
#                          'participantId': 6,
#                          'skillSlot': 2,
#                          'timestamp': 148536,
#                          'type': 'SKILL_LEVEL_UP'},
#                         {'creatorId': 10,
#                          'timestamp': 150879,
#                          'type': 'WARD_PLACED',
#                          'wardType': 'YELLOW_TRINKET'},
#                         {'levelUpType': 'NORMAL',
#                          'participantId': 4,
#                          'skillSlot': 1,
#                          'timestamp': 151671,
#                          'type': 'SKILL_LEVEL_UP'},
#                         {'levelUpType': 'NORMAL',
#                          'participantId': 7,
#                          'skillSlot': 2,
#                          'timestamp': 163321,
#                          'type': 'SKILL_LEVEL_UP'},
#                         {'levelUpType': 'NORMAL',
#                          'participantId': 1,
#                          'skillSlot': 2,
#                          'timestamp': 163651,
#                          'type': 'SKILL_LEVEL_UP'},
#                         {'levelUpType': 'NORMAL',
#                          'participantId': 3,
#                          'skillSlot': 3,
#                          'timestamp': 163684,
#                          'type': 'SKILL_LEVEL_UP'},
#                         {'assistingParticipantIds': [],
#                          'killerId': 10,
#                          'position': {'x': 3298, 'y': 13212},
#                          'timestamp': 163783,
#                          'type': 'CHAMPION_KILL',
#                          'victimId': 5},
#                         {'levelUpType': 'NORMAL',
#                          'participantId': 2,
#                          'skillSlot': 2,
#                          'timestamp': 165895,
#                          'type': 'SKILL_LEVEL_UP'},
#                         {'itemId': 2003,
#                          'participantId': 9,
#                          'timestamp': 169030,
#                          'type': 'ITEM_DESTROYED'},
#                         {'levelUpType': 'NORMAL',
#                          'participantId': 10,
#                          'skillSlot': 2,
#                          'timestamp': 174112,
#                          'type': 'SKILL_LEVEL_UP'},
#                         {'itemId': 3801,
#                          'participantId': 5,
#                          'timestamp': 176290,
#                          'type': 'ITEM_PURCHASED'},
#                         {'itemId': 1006,
#                          'participantId': 5,
#                          'timestamp': 176290,
#                          'type': 'ITEM_DESTROYED'},
#                         {'afterId': 0,
#                          'beforeId': 3801,
#                          'participantId': 5,
#                          'timestamp': 177313,
#                          'type': 'ITEM_UNDO'},
#                         {'itemId': 1001,
#                          'participantId': 5,
#                          'timestamp': 178039,
#                          'type': 'ITEM_PURCHASED'}],
#              'participantFrames': {'1': {'currentGold': 232,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 0,
#                                          'level': 2,
#                                          'minionsKilled': 0,
#                                          'participantId': 1,
#                                          'position': {'x': 12372, 'y': 1500},
#                                          'teamScore': 0,
#                                          'totalGold': 732,
#                                          'xp': 441},
#                                    '10': {'currentGold': 760,
#                                           'dominionScore': 0,
#                                           'jungleMinionsKilled': 0,
#                                           'level': 3,
#                                           'minionsKilled': 12,
#                                           'participantId': 10,
#                                           'position': {'x': 2333, 'y': 12124},
#                                           'teamScore': 0,
#                                           'totalGold': 1260,
#                                           'xp': 801},
#                                    '2': {'currentGold': 388,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 0,
#                                          'level': 3,
#                                          'minionsKilled': 14,
#                                          'participantId': 2,
#                                          'position': {'x': 6450, 'y': 6676},
#                                          'teamScore': 0,
#                                          'totalGold': 888,
#                                          'xp': 886},
#                                    '3': {'currentGold': 270,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 0,
#                                          'level': 2,
#                                          'minionsKilled': 7,
#                                          'participantId': 3,
#                                          'position': {'x': 11987, 'y': 1755},
#                                          'teamScore': 0,
#                                          'totalGold': 770,
#                                          'xp': 441},
#                                    '4': {'currentGold': 283,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 0,
#                                          'level': 2,
#                                          'minionsKilled': 8,
#                                          'participantId': 4,
#                                          'position': {'x': 1266, 'y': 11563},
#                                          'teamScore': 0,
#                                          'totalGold': 783,
#                                          'xp': 559},
#                                    '5': {'currentGold': 113,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 12,
#                                          'level': 2,
#                                          'minionsKilled': 0,
#                                          'participantId': 5,
#                                          'position': {'x': 914, 'y': 670},
#                                          'teamScore': 0,
#                                          'totalGold': 913,
#                                          'xp': 615},
#                                    '6': {'currentGold': 332,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 0,
#                                          'level': 2,
#                                          'minionsKilled': 11,
#                                          'participantId': 6,
#                                          'position': {'x': 12815, 'y': 2541},
#                                          'teamScore': 0,
#                                          'totalGold': 832,
#                                          'xp': 422},
#                                    '7': {'currentGold': 311,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 0,
#                                          'level': 3,
#                                          'minionsKilled': 9,
#                                          'participantId': 7,
#                                          'position': {'x': 7615, 'y': 7601},
#                                          'teamScore': 0,
#                                          'totalGold': 811,
#                                          'xp': 706},
#                                    '8': {'currentGold': 415,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 13,
#                                          'level': 2,
#                                          'minionsKilled': 0,
#                                          'participantId': 8,
#                                          'position': {'x': 11241, 'y': 8666},
#                                          'teamScore': 0,
#                                          'totalGold': 915,
#                                          'xp': 640},
#                                    '9': {'currentGold': 199,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 0,
#                                          'level': 2,
#                                          'minionsKilled': 3,
#                                          'participantId': 9,
#                                          'position': {'x': 13269, 'y': 2262},
#                                          'teamScore': 0,
#                                          'totalGold': 699,
#                                          'xp': 422}},
#              'timestamp': 180052},
#             {'events': [{'itemId': 2003,
#                          'participantId': 2,
#                          'timestamp': 180154,
#                          'type': 'ITEM_DESTROYED'},
#                         {'levelUpType': 'NORMAL',
#                          'participantId': 8,
#                          'skillSlot': 3,
#                          'timestamp': 183355,
#                          'type': 'SKILL_LEVEL_UP'},
#                         {'itemId': 2062,
#                          'participantId': 3,
#                          'timestamp': 189362,
#                          'type': 'ITEM_DESTROYED'},
#                         {'itemId': 2004,
#                          'participantId': 3,
#                          'timestamp': 190588,
#                          'type': 'ITEM_DESTROYED'},
#                         {'levelUpType': 'NORMAL',
#                          'participantId': 10,
#                          'skillSlot': 1,
#                          'timestamp': 195538,
#                          'type': 'SKILL_LEVEL_UP'},
#                         {'levelUpType': 'NORMAL',
#                          'participantId': 4,
#                          'skillSlot': 3,
#                          'timestamp': 198871,
#                          'type': 'SKILL_LEVEL_UP'},
#                         {'assistingParticipantIds': [],
#                          'killerId': 7,
#                          'position': {'x': 6825, 'y': 6917},
#                          'timestamp': 198970,
#                          'type': 'CHAMPION_KILL',
#                          'victimId': 2},
#                         {'assistingParticipantIds': [],
#                          'killerId': 2,
#                          'position': {'x': 6756, 'y': 6722},
#                          'timestamp': 199465,
#                          'type': 'CHAMPION_KILL',
#                          'victimId': 7},
#                         {'itemId': 1051,
#                          'participantId': 2,
#                          'timestamp': 207286,
#                          'type': 'ITEM_PURCHASED'},
#                         {'itemId': 1042,
#                          'participantId': 2,
#                          'timestamp': 207847,
#                          'type': 'ITEM_PURCHASED'},
#                         {'levelUpType': 'NORMAL',
#                          'participantId': 2,
#                          'skillSlot': 1,
#                          'timestamp': 210652,
#                          'type': 'SKILL_LEVEL_UP'},
#                         {'levelUpType': 'NORMAL',
#                          'participantId': 5,
#                          'skillSlot': 2,
#                          'timestamp': 211411,
#                          'type': 'SKILL_LEVEL_UP'},
#                         {'itemId': 2003,
#                          'participantId': 2,
#                          'timestamp': 212203,
#                          'type': 'ITEM_PURCHASED'},
#                         {'itemId': 1036,
#                          'participantId': 7,
#                          'timestamp': 212764,
#                          'type': 'ITEM_PURCHASED'},
#                         {'levelUpType': 'NORMAL',
#                          'participantId': 6,
#                          'skillSlot': 3,
#                          'timestamp': 212797,
#                          'type': 'SKILL_LEVEL_UP'},
#                         {'itemId': 1001,
#                          'participantId': 7,
#                          'timestamp': 214315,
#                          'type': 'ITEM_PURCHASED'},
#                         {'levelUpType': 'NORMAL',
#                          'participantId': 1,
#                          'skillSlot': 3,
#                          'timestamp': 214546,
#                          'type': 'SKILL_LEVEL_UP'},
#                         {'levelUpType': 'NORMAL',
#                          'participantId': 3,
#                          'skillSlot': 1,
#                          'timestamp': 214711,
#                          'type': 'SKILL_LEVEL_UP'},
#                         {'afterId': 0,
#                          'beforeId': 1001,
#                          'participantId': 7,
#                          'timestamp': 215404,
#                          'type': 'ITEM_UNDO'},
#                         {'afterId': 0,
#                          'beforeId': 1036,
#                          'participantId': 7,
#                          'timestamp': 215867,
#                          'type': 'ITEM_UNDO'},
#                         {'itemId': 1001,
#                          'participantId': 7,
#                          'timestamp': 218177,
#                          'type': 'ITEM_PURCHASED'},
#                         {'levelUpType': 'NORMAL',
#                          'participantId': 9,
#                          'skillSlot': 3,
#                          'timestamp': 219002,
#                          'type': 'SKILL_LEVEL_UP'},
#                         {'itemId': 1028,
#                          'participantId': 7,
#                          'timestamp': 220820,
#                          'type': 'ITEM_PURCHASED'},
#                         {'itemId': 2055,
#                          'participantId': 7,
#                          'timestamp': 222173,
#                          'type': 'ITEM_PURCHASED'},
#                         {'levelUpType': 'NORMAL',
#                          'participantId': 4,
#                          'skillSlot': 2,
#                          'timestamp': 224054,
#                          'type': 'SKILL_LEVEL_UP'},
#                         {'itemId': 2003,
#                          'participantId': 3,
#                          'timestamp': 227123,
#                          'type': 'ITEM_DESTROYED'},
#                         {'levelUpType': 'NORMAL',
#                          'participantId': 8,
#                          'skillSlot': 1,
#                          'timestamp': 229104,
#                          'type': 'SKILL_LEVEL_UP'},
#                         {'creatorId': 1,
#                          'timestamp': 231513,
#                          'type': 'WARD_PLACED',
#                          'wardType': 'YELLOW_TRINKET'},
#                         {'itemId': 2003,
#                          'participantId': 6,
#                          'timestamp': 237948,
#                          'type': 'ITEM_DESTROYED'},
#                         {'assistingParticipantIds': [3, 1],
#                          'killerId': 5,
#                          'position': {'x': 13178, 'y': 3625},
#                          'timestamp': 238806,
#                          'type': 'CHAMPION_KILL',
#                          'victimId': 6}],
#              'participantFrames': {'1': {'currentGold': 463,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 0,
#                                          'level': 3,
#                                          'minionsKilled': 1,
#                                          'participantId': 1,
#                                          'position': {'x': 13267, 'y': 3446},
#                                          'teamScore': 0,
#                                          'totalGold': 963,
#                                          'xp': 764},
#                                    '10': {'currentGold': 1009,
#                                           'dominionScore': 0,
#                                           'jungleMinionsKilled': 0,
#                                           'level': 4,
#                                           'minionsKilled': 19,
#                                           'participantId': 10,
#                                           'position': {'x': 1582, 'y': 11276},
#                                           'teamScore': 0,
#                                           'totalGold': 1509,
#                                           'xp': 1511},
#                                    '2': {'currentGold': 82,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 0,
#                                          'level': 4,
#                                          'minionsKilled': 15,
#                                          'participantId': 2,
#                                          'position': {'x': 6876, 'y': 7976},
#                                          'teamScore': 0,
#                                          'totalGold': 1332,
#                                          'xp': 1247},
#                                    '3': {'currentGold': 548,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 0,
#                                          'level': 3,
#                                          'minionsKilled': 11,
#                                          'participantId': 3,
#                                          'position': {'x': 13034, 'y': 3198},
#                                          'teamScore': 0,
#                                          'totalGold': 1048,
#                                          'xp': 764},
#                                    '4': {'currentGold': 602,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 0,
#                                          'level': 4,
#                                          'minionsKilled': 18,
#                                          'participantId': 4,
#                                          'position': {'x': 1269, 'y': 10888},
#                                          'teamScore': 0,
#                                          'totalGold': 1102,
#                                          'xp': 1357},
#                                    '5': {'currentGold': 656,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 16,
#                                          'level': 3,
#                                          'minionsKilled': 0,
#                                          'participantId': 5,
#                                          'position': {'x': 13402, 'y': 3626},
#                                          'teamScore': 0,
#                                          'totalGold': 1456,
#                                          'xp': 831},
#                                    '6': {'currentGold': 595,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 0,
#                                          'level': 3,
#                                          'minionsKilled': 19,
#                                          'participantId': 6,
#                                          'position': {'x': 13178, 'y': 3625},
#                                          'teamScore': 0,
# ...
#                          'timestamp': 2084805,
#                          'type': 'WARD_PLACED',
#                          'wardType': 'YELLOW_TRINKET'},
#                         {'creatorId': 5,
#                          'timestamp': 2085135,
#                          'type': 'WARD_PLACED',
#                          'wardType': 'YELLOW_TRINKET'}],
#              'participantFrames': {'1': {'currentGold': 729,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 6,
#                                          'level': 14,
#                                          'minionsKilled': 73,
#                                          'participantId': 1,
#                                          'position': {'x': 9950, 'y': 8749},
#                                          'teamScore': 0,
#                                          'totalGold': 10298,
#                                          'xp': 11942},
#                                    '10': {'currentGold': 893,
#                                           'dominionScore': 0,
#                                           'jungleMinionsKilled': 28,
#                                           'level': 17,
#                                           'minionsKilled': 219,
#                                           'participantId': 10,
#                                           'position': {'x': 10314, 'y': 9596},
#                                           'teamScore': 0,
#                                           'totalGold': 11817,
#                                           'xp': 16591},
#                                    '2': {'currentGold': 191,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 12,
#                                          'level': 17,
#                                          'minionsKilled': 264,
#                                          'participantId': 2,
#                                          'position': {'x': 9098, 'y': 8420},
#                                          'teamScore': 0,
#                                          'totalGold': 14236,
#                                          'xp': 17016},
#                                    '3': {'currentGold': 451,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 14,
#                                          'level': 15,
#                                          'minionsKilled': 134,
#                                          'participantId': 3,
#                                          'position': {'x': 8693, 'y': 8894},
#                                          'teamScore': 0,
#                                          'totalGold': 11458,
#                                          'xp': 14487},
#                                    '4': {'currentGold': 876,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 29,
#                                          'level': 17,
#                                          'minionsKilled': 185,
#                                          'participantId': 4,
#                                          'position': {'x': 9905, 'y': 7818},
#                                          'teamScore': 0,
#                                          'totalGold': 14625,
#                                          'xp': 17840},
#                                    '5': {'currentGold': 392,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 130,
#                                          'level': 15,
#                                          'minionsKilled': 21,
#                                          'participantId': 5,
#                                          'position': {'x': 8487, 'y': 8220},
#                                          'teamScore': 0,
#                                          'totalGold': 10867,
#                                          'xp': 14265},
#                                    '6': {'currentGold': 888,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 19,
#                                          'level': 15,
#                                          'minionsKilled': 223,
#                                          'participantId': 6,
#                                          'position': {'x': 9500, 'y': 10114},
#                                          'teamScore': 0,
#                                          'totalGold': 13813,
#                                          'xp': 14129},
#                                    '7': {'currentGold': 1458,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 30,
#                                          'level': 17,
#                                          'minionsKilled': 220,
#                                          'participantId': 7,
#                                          'position': {'x': 9975, 'y': 9560},
#                                          'teamScore': 0,
#                                          'totalGold': 16265,
#                                          'xp': 17691},
#                                    '8': {'currentGold': 696,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 106,
#                                          'level': 15,
#                                          'minionsKilled': 45,
#                                          'participantId': 8,
#                                          'position': {'x': 10598, 'y': 9085},
#                                          'teamScore': 0,
#                                          'totalGold': 9845,
#                                          'xp': 13707},
#                                    '9': {'currentGold': 541,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 0,
#                                          'level': 13,
#                                          'minionsKilled': 59,
#                                          'participantId': 9,
#                                          'position': {'x': 9844, 'y': 9941},
#                                          'teamScore': 0,
#                                          'totalGold': 8741,
#                                          'xp': 11143}},
#              'timestamp': 2100654},
#             {'events': [{'creatorId': 4,
#                          'timestamp': 2108518,
#                          'type': 'WARD_PLACED',
#                          'wardType': 'BLUE_TRINKET'},
#                         {'killerId': 10,
#                          'timestamp': 2110531,
#                          'type': 'WARD_KILL',
#                          'wardType': 'BLUE_TRINKET'},
#                         {'creatorId': 2,
#                          'timestamp': 2133772,
#                          'type': 'WARD_PLACED',
#                          'wardType': 'UNDEFINED'},
#                         {'assistingParticipantIds': [2],
#                          'killerId': 1,
#                          'position': {'x': 7602, 'y': 7122},
#                          'timestamp': 2136232,
#                          'type': 'CHAMPION_KILL',
#                          'victimId': 8},
#                         {'levelUpType': 'NORMAL',
#                          'participantId': 5,
#                          'skillSlot': 4,
#                          'timestamp': 2136430,
#                          'type': 'SKILL_LEVEL_UP'},
#                         {'levelUpType': 'NORMAL',
#                          'participantId': 3,
#                          'skillSlot': 4,
#                          'timestamp': 2137453,
#                          'type': 'SKILL_LEVEL_UP'},
#                         {'assistingParticipantIds': [1],
#                          'killerId': 2,
#                          'position': {'x': 8206, 'y': 6777},
#                          'timestamp': 2138756,
#                          'type': 'CHAMPION_KILL',
#                          'victimId': 6},
#                         {'assistingParticipantIds': [2, 3, 1],
#                          'killerId': 4,
#                          'position': {'x': 7994, 'y': 6987},
#                          'timestamp': 2141877,
#                          'type': 'CHAMPION_KILL',
#                          'victimId': 7},
#                         {'levelUpType': 'NORMAL',
#                          'participantId': 4,
#                          'skillSlot': 2,
#                          'timestamp': 2145199,
#                          'type': 'SKILL_LEVEL_UP'},
#                         {'assistingParticipantIds': [4, 3, 1],
#                          'killerId': 2,
#                          'position': {'x': 8080, 'y': 6935},
#                          'timestamp': 2145797,
#                          'type': 'CHAMPION_KILL',
#                          'victimId': 9},
#                         {'levelUpType': 'NORMAL',
#                          'participantId': 1,
#                          'skillSlot': 3,
#                          'timestamp': 2147512,
#                          'type': 'SKILL_LEVEL_UP'},
#                         {'itemId': 2059,
#                          'participantId': 3,
#                          'timestamp': 2148469,
#                          'type': 'ITEM_DESTROYED'},
#                         {'assistingParticipantIds': [2, 3, 1],
#                          'killerId': 4,
#                          'position': {'x': 7558, 'y': 8075},
#                          'timestamp': 2148800,
#                          'type': 'CHAMPION_KILL',
#                          'victimId': 10}],
#              'participantFrames': {'1': {'currentGold': 1669,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 6,
#                                          'level': 15,
#                                          'minionsKilled': 77,
#                                          'participantId': 1,
#                                          'position': {'x': 9568, 'y': 9788},
#                                          'teamScore': 0,
#                                          'totalGold': 11239,
#                                          'xp': 13487},
#                                    '10': {'currentGold': 1130,
#                                           'dominionScore': 0,
#                                           'jungleMinionsKilled': 32,
#                                           'level': 17,
#                                           'minionsKilled': 220,
#                                           'participantId': 10,
#                                           'position': {'x': 7558, 'y': 8075},
#                                           'teamScore': 0,
#                                           'totalGold': 12055,
#                                           'xp': 16908},
#                                    '2': {'currentGold': 1295,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 12,
#                                          'level': 17,
#                                          'minionsKilled': 268,
#                                          'participantId': 2,
#                                          'position': {'x': 9647, 'y': 9724},
#                                          'teamScore': 0,
#                                          'totalGold': 15340,
#                                          'xp': 18085},
#                                    '3': {'currentGold': 873,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 14,
#                                          'level': 16,
#                                          'minionsKilled': 138,
#                                          'participantId': 3,
#                                          'position': {'x': 9923, 'y': 10057},
#                                          'teamScore': 0,
#                                          'totalGold': 11880,
#                                          'xp': 15518},
#                                    '4': {'currentGold': 2158,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 29,
#                                          'level': 18,
#                                          'minionsKilled': 195,
#                                          'participantId': 4,
#                                          'position': {'x': 9693, 'y': 9780},
#                                          'teamScore': 0,
#                                          'totalGold': 15907,
#                                          'xp': 18958},
#                                    '5': {'currentGold': 748,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 138,
#                                          'level': 16,
#                                          'minionsKilled': 22,
#                                          'participantId': 5,
#                                          'position': {'x': 9999, 'y': 10010},
#                                          'teamScore': 0,
#                                          'totalGold': 11222,
#                                          'xp': 15472},
#                                    '6': {'currentGold': 1137,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 19,
#                                          'level': 15,
#                                          'minionsKilled': 230,
#                                          'participantId': 6,
#                                          'position': {'x': 8206, 'y': 6777},
#                                          'teamScore': 0,
#                                          'totalGold': 14061,
#                                          'xp': 14296},
#                                    '7': {'currentGold': 1622,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 30,
#                                          'level': 17,
#                                          'minionsKilled': 222,
#                                          'participantId': 7,
#                                          'position': {'x': 7994, 'y': 6987},
#                                          'teamScore': 0,
#                                          'totalGold': 16429,
#                                          'xp': 17845},
#                                    '8': {'currentGold': 922,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 106,
#                                          'level': 15,
#                                          'minionsKilled': 47,
#                                          'participantId': 8,
#                                          'position': {'x': 7602, 'y': 7122},
#                                          'teamScore': 0,
#                                          'totalGold': 10072,
#                                          'xp': 13851},
#                                    '9': {'currentGold': 684,
#                                          'dominionScore': 0,
#                                          'jungleMinionsKilled': 0,
#                                          'level': 13,
#                                          'minionsKilled': 60,
#                                          'participantId': 9,
#                                          'position': {'x': 8080, 'y': 6935},
#                                          'teamScore': 0,
#                                          'totalGold': 8883,
#                                          'xp': 11346}},
#              'timestamp': 2160677}]}

# %%
summoner_name = "야너어어어엌"
account_id = get_account_id(summoner_name)

# %%
# participants: dictionary > stats: dictionary > totalDamageDealtToChampions	
detail = get_game_detail(3309773060)
damage = [p['stats']['totalDamageDealtToChampions'] for p in detail['participants']]

# %%
pprint(detail)
# Out:
# {'gameCreation': 1534397053925,
#  'gameDuration': 2163,
#  'gameId': 3309773060,
#  'gameMode': 'CLASSIC',
#  'gameType': 'MATCHED_GAME',
#  'gameVersion': '8.16.241.6543',
#  'mapId': 11,
#  'participantIdentities': [{'participantId': 1,
#                             'player': {'accountId': 'sCfZQlHFe_rTMpYgcHw3vZZ4cU8DPmKEq5wcggijNWjH',
#                                        'currentAccountId': 'sCfZQlHFe_rTMpYgcHw3vZZ4cU8DPmKEq5wcggijNWjH',
#                                        'currentPlatformId': 'KR',
#                                        'matchHistoryUri': '/v1/stats/player_history/KR/5340788',
#                                        'platformId': 'KR',
#                                        'profileIcon': 3551,
#                                        'summonerId': '_D2FamvJ0DuoDVcUgatmVMuAriEX3gyrMVJGNfdK1D7j7g',
#                                        'summonerName': 'TACTRAS'}},
#                            {'participantId': 2,
#                             'player': {'accountId': 'Nzb_hkwwJPSHU7Lb2GHWTlzKBphLKMlOYBipQBC8nQgxBus',
#                                        'currentAccountId': 'Nzb_hkwwJPSHU7Lb2GHWTlzKBphLKMlOYBipQBC8nQgxBus',
#                                        'currentPlatformId': 'KR',
#                                        'matchHistoryUri': '/v1/stats/player_history/KR/209843654',
#                                        'platformId': 'KR',
#                                        'profileIcon': 3556,
#                                        'summonerId': 'SSRcCxcS2tlf771M16EKsviVzvKzZ666oz5twID_Dd8F1k8',
#                                        'summonerName': '유니크설계'}},
#                            {'participantId': 3,
#                             'player': {'accountId': '0kL0TZSGqrAFBw-2mkkjRCRxzt_5E0qsZ-SscoYmFuRnzN0',
#                                        'currentAccountId': '0kL0TZSGqrAFBw-2mkkjRCRxzt_5E0qsZ-SscoYmFuRnzN0',
#                                        'currentPlatformId': 'KR',
#                                        'matchHistoryUri': '/v1/stats/player_history/KR/209267072',
#                                        'platformId': 'KR',
#                                        'profileIcon': 1589,
#                                        'summonerId': 'Wk6gakGARbyPzv9yCnXR1_jEl-pR_ZpLlsEDfKB_l4QKeTo',
#                                        'summonerName': 'Ez 세레MONEY'}},
#                            {'participantId': 4,
#                             'player': {'accountId': '5Amh38bsuzXul2KF0NODUuAoB2cELstq0GNIyCwwq5Zpe5g',
#                                        'currentAccountId': '5Amh38bsuzXul2KF0NODUuAoB2cELstq0GNIyCwwq5Zpe5g',
#                                        'currentPlatformId': 'KR',
#                                        'matchHistoryUri': '/v1/stats/player_history/KR/207219009',
#                                        'platformId': 'KR',
#                                        'profileIcon': 3553,
#                                        'summonerId': 'QOsMOQgGbBUs1BUZ9x_tfjFtk17EU2GOPSIBJHcUoxCD1Yk',
#                                        'summonerName': '안녕십자인대'}},
#                            {'participantId': 5,
#                             'player': {'accountId': 'gocz-AettAtIwctHUL_dPOXRlhlzthwUPCccO3DMaRJLRQU',
#                                        'currentAccountId': 'gocz-AettAtIwctHUL_dPOXRlhlzthwUPCccO3DMaRJLRQU',
#                                        'currentPlatformId': 'KR',
#                                        'matchHistoryUri': '/v1/stats/player_history/KR/210254235',
#                                        'platformId': 'KR',
#                                        'profileIcon': 4,
#                                        'summonerId': 'LU7kvlZGUeGEa9LgcAh-mmVdlKF5NOudiU_tKEZE5VgAjSg',
#                                        'summonerName': '노빡구123'}},
#                            {'participantId': 6,
#                             'player': {'accountId': 'CNEtJXCg2otW-KY1EyHQIYfxda1hkW3-V3ulZXCcpYUXSak',
#                                        'currentAccountId': 'CNEtJXCg2otW-KY1EyHQIYfxda1hkW3-V3ulZXCcpYUXSak',
#                                        'currentPlatformId': 'KR',
#                                        'matchHistoryUri': '/v1/stats/player_history/KR/204084903',
#                                        'platformId': 'KR',
#                                        'profileIcon': 3587,
#                                        'summonerId': 'eqr7WvCegE69N1aD_oGrjUq7Mo5FwF08e9xxPgC7TO1q9G8',
#                                        'summonerName': '일회용생성물'}},
#                            {'participantId': 7,
#                             'player': {'accountId': '4km1QPNT0eUUjYLbt1Vugxh4hGPFN4CgM9VJ0A9rTCFi',
#                                        'currentAccountId': '4km1QPNT0eUUjYLbt1Vugxh4hGPFN4CgM9VJ0A9rTCFi',
#                                        'currentPlatformId': 'KR',
#                                        'matchHistoryUri': '/v1/stats/player_history/KR/5925715',
#                                        'platformId': 'KR',
#                                        'profileIcon': 1301,
#                                        'summonerId': '9tVRTJkFQ9-r2RCL9YQNJSr2g6ya3ycXR6Q6xr0mcgL6yg',
#                                        'summonerName': '야너어어어엌'}},
#                            {'participantId': 8,
#                             'player': {'accountId': 'x8khdSflDaAz34GQH2kVRxGQIrORDiFOzeuSd010FlKRsf0',
#                                        'currentAccountId': 'x8khdSflDaAz34GQH2kVRxGQIrORDiFOzeuSd010FlKRsf0',
#                                        'currentPlatformId': 'KR',
#                                        'matchHistoryUri': '/v1/stats/player_history/KR/204706442',
#                                        'platformId': 'KR',
#                                        'profileIcon': 1382,
#                                        'summonerId': 'kdJReE-w0pGsczP3pEeayHmHcntTNYbprj-Fud3G_QWuCNE',
#                                        'summonerName': '잘굴러간다'}},
#                            {'participantId': 9,
#                             'player': {'accountId': 'oBQsMLM8EJXRZ-hiihQBSvvwVNGCgURuNqBWokA-EJFzYnI',
#                                        'currentAccountId': 'oBQsMLM8EJXRZ-hiihQBSvvwVNGCgURuNqBWokA-EJFzYnI',
#                                        'currentPlatformId': 'KR',
#                                        'matchHistoryUri': '/v1/stats/player_history/KR/209838347',
#                                        'platformId': 'KR',
#                                        'profileIcon': 3587,
#                                        'summonerId': 'kRqKxSHz5tiYYft3cLwQ4txjsPtKIIE-Klrv9CfM7T2SSiM',
#                                        'summonerName': '냉면한사라'}},
#                            {'participantId': 10,
#                             'player': {'accountId': 'tzUwf4Z79LBnyGEQjAbRPfOWhCKDU-qBzYopwNEo6KwkKlQ',
#                                        'currentAccountId': 'tzUwf4Z79LBnyGEQjAbRPfOWhCKDU-qBzYopwNEo6KwkKlQ',
#                                        'currentPlatformId': 'KR',
#                                        'matchHistoryUri': '/v1/stats/player_history/KR/204789361',
#                                        'platformId': 'KR',
#                                        'profileIcon': 3554,
#                                        'summonerId': 'hdxzkap9qLU4mVDFN93ahDnAh3UhjjEP-gopHDdYYyxX3BQ',
#                                        'summonerName': '100일정지된본캐'}}],
#  'participants': [{'championId': 31,
#                    'highestAchievedSeasonTier': 'SILVER',
#                    'participantId': 1,
#                    'spell1Id': 4,
#                    'spell2Id': 12,
#                    'stats': {'assists': 13,
#                              'champLevel': 15,
#                              'combatPlayerScore': 0,
#                              'damageDealtToObjectives': 2352,
#                              'damageDealtToTurrets': 1252,
#                              'damageSelfMitigated': 13499,
#                              'deaths': 7,
#                              'doubleKills': 0,
#                              'firstBloodAssist': False,
#                              'firstBloodKill': False,
#                              'firstTowerAssist': False,
#                              'firstTowerKill': False,
#                              'goldEarned': 11246,
#                              'goldSpent': 9600,
#                              'inhibitorKills': 0,
#                              'item0': 3027,
#                              'item1': 3096,
#                              'item2': 3083,
#                              'item3': 3117,
#                              'item4': 1011,
#                              'item5': 3082,
#                              'item6': 3364,
#                              'killingSprees': 1,
#                              'kills': 5,
#                              'largestCriticalStrike': 0,
#                              'largestKillingSpree': 4,
#                              'largestMultiKill': 1,
#                              'longestTimeSpentLiving': 467,
#                              'magicDamageDealt': 73802,
#                              'magicDamageDealtToChampions': 10540,
#                              'magicalDamageTaken': 18297,
#                              'neutralMinionsKilled': 6,
#                              'neutralMinionsKilledEnemyJungle': 4,
#                              'neutralMinionsKilledTeamJungle': 2,
#                              'objectivePlayerScore': 0,
#                              'participantId': 1,
#                              'pentaKills': 0,
#                              'perk0': 8229,
#                              'perk0Var1': 1416,
#                              'perk0Var2': 0,
#                              'perk0Var3': 0,
#                              'perk1': 8226,
#                              'perk1Var1': 250,
#                              'perk1Var2': 638,
#                              'perk1Var3': 0,
#                              'perk2': 8210,
#                              'perk2Var1': 0,
#                              'perk2Var2': 0,
#                              'perk2Var3': 0,
#                              'perk3': 8237,
#                              'perk3Var1': 353,
#                              'perk3Var2': 0,
#                              'perk3Var3': 0,
#                              'perk4': 8017,
#                              'perk4Var1': 79,
#                              'perk4Var2': 0,
#                              'perk4Var3': 0,
#                              'perk5': 8009,
#                              'perk5Var1': 2136,
#                              'perk5Var2': 68,
#                              'perk5Var3': 0,
#                              'perkPrimaryStyle': 8200,
#                              'perkSubStyle': 8000,
#                              'physicalDamageDealt': 8436,
#                              'physicalDamageDealtToChampions': 725,
#                              'physicalDamageTaken': 13918,
#                              'playerScore0': 0,
#                              'playerScore1': 0,
#                              'playerScore2': 0,
#                              'playerScore3': 0,
#                              'playerScore4': 0,
#                              'playerScore5': 0,
#                              'playerScore6': 0,
#                              'playerScore7': 0,
#                              'playerScore8': 0,
#                              'playerScore9': 0,
#                              'quadraKills': 0,
#                              'sightWardsBoughtInGame': 0,
#                              'timeCCingOthers': 85,
#                              'totalDamageDealt': 91702,
#                              'totalDamageDealtToChampions': 14220,
#                              'totalDamageTaken': 33318,
#                              'totalHeal': 3830,
#                              'totalMinionsKilled': 77,
#                              'totalPlayerScore': 0,
#                              'totalScoreRank': 0,
#                              'totalTimeCrowdControlDealt': 688,
#                              'totalUnitsHealed': 1,
#                              'tripleKills': 0,
#                              'trueDamageDealt': 9463,
#                              'trueDamageDealtToChampions': 2954,
#                              'trueDamageTaken': 1101,
#                              'turretKills': 0,
#                              'unrealKills': 0,
#                              'visionScore': 57,
#                              'visionWardsBoughtInGame': 2,
#                              'wardsKilled': 4,
#                              'wardsPlaced': 22,
#                              'win': True},
#                    'teamId': 100,
#                    'timeline': {'creepsPerMinDeltas': {'0-10': 0.4,
#                                                        '10-20': 2.8,
#                                                        '20-30': 2.8,
#                                                        '30-end': 2.6},
#                                 'csDiffPerMinDeltas': {'0-10': -1.45,
#                                                        '10-20': -1.4000000000000001,
#                                                        '20-30': -1.1500000000000004,
#                                                        '30-end': 0.5},
#                                 'damageTakenDiffPerMinDeltas': {'0-10': -140.40000000000003,
#                                                                 '10-20': -14.350000000000051,
#                                                                 '20-30': -335.65,
#                                                                 '30-end': 351.79999999999995},
#                                 'damageTakenPerMinDeltas': {'0-10': 363.2,
#                                                             '10-20': 778.0999999999999,
#                                                             '20-30': 1131.1,
#                                                             '30-end': 1725},
#                                 'goldPerMinDeltas': {'0-10': 173.10000000000002,
#                                                      '10-20': 266.6,
#                                                      '20-30': 380.9,
#                                                      '30-end': 318.4},
#                                 'lane': 'BOTTOM',
#                                 'participantId': 1,
#                                 'role': 'DUO_SUPPORT',
#                                 'xpDiffPerMinDeltas': {'0-10': 1.4999999999999858,
#                                                        '10-20': -34.44999999999999,
#                                                        '20-30': 143.75,
#                                                        '30-end': -105.90000000000003},
#                                 'xpPerMinDeltas': {'0-10': 268.29999999999995,
#                                                    '10-20': 356.5,
#                                                    '20-30': 431.29999999999995,
#                                                    '30-end': 276.2}}},
#                   {'championId': 157,
#                    'highestAchievedSeasonTier': 'UNRANKED',
#                    'participantId': 2,
#                    'spell1Id': 14,
#                    'spell2Id': 4,
#                    'stats': {'assists': 8,
#                              'champLevel': 17,
#                              'combatPlayerScore': 0,
#                              'damageDealtToObjectives': 5879,
#                              'damageDealtToTurrets': 910,
#                              'damageSelfMitigated': 23187,
#                              'deaths': 6,
#                              'doubleKills': 4,
#                              'firstBloodAssist': False,
#                              'firstBloodKill': False,
#                              'firstTowerAssist': False,
#                              'firstTowerKill': False,
#                              'goldEarned': 15346,
#                              'goldSpent': 14225,
#                              'inhibitorKills': 0,
#                              'item0': 3031,
#                              'item1': 3143,
#                              'item2': 3006,
#                              'item3': 3072,
#                              'item4': 3046,
#                              'item5': 0,
#                              'item6': 3340,
#                              'killingSprees': 4,
#                              'kills': 11,
#                              'largestCriticalStrike': 633,
#                              'largestKillingSpree': 4,
#                              'largestMultiKill': 2,
#                              'longestTimeSpentLiving': 847,
#                              'magicDamageDealt': 11911,
#                              'magicDamageDealtToChampions': 1228,
#                              'magicalDamageTaken': 12800,
#                              'neutralMinionsKilled': 12,
#                              'neutralMinionsKilledEnemyJungle': 0,
#                              'neutralMinionsKilledTeamJungle': 5,
#                              'objectivePlayerScore': 0,
#                              'participantId': 2,
#                              'pentaKills': 0,
#                              'perk0': 8010,
#                              'perk0Var1': 3081,
#                              'perk0Var2': 0,
#                              'perk0Var3': 0,
#                              'perk1': 9111,
#                              'perk1Var1': 1954,
#                              'perk1Var2': 380,
#                              'perk1Var3': 0,
#                              'perk2': 9104,
#                              'perk2Var1': 18,
#                              'perk2Var2': 0,
#                              'perk2Var3': 0,
#                              'perk3': 8014,
#                              'perk3Var1': 457,
#                              'perk3Var2': 0,
#                              'perk3Var3': 0,
#                              'perk4': 8473,
#                              'perk4Var1': 468,
#                              'perk4Var2': 0,
#                              'perk4Var3': 0,
#                              'perk5': 8451,
#                              'perk5Var1': 246,
#                              'perk5Var2': 0,
#                              'perk5Var3': 0,
#                              'perkPrimaryStyle': 8000,
#                              'perkSubStyle': 8400,
#                              'physicalDamageDealt': 193054,
#                              'physicalDamageDealtToChampions': 20922,
#                              'physicalDamageTaken': 8530,
#                              'playerScore0': 0,
#                              'playerScore1': 0,
#                              'playerScore2': 0,
#                              'playerScore3': 0,
#                              'playerScore4': 0,
#                              'playerScore5': 0,
#                              'playerScore6': 0,
#                              'playerScore7': 0,
#                              'playerScore8': 0,
#                              'playerScore9': 0,
#                              'quadraKills': 0,
#                              'sightWardsBoughtInGame': 0,
#                              'timeCCingOthers': 35,
#                              'totalDamageDealt': 222336,
#                              'totalDamageDealtToChampions': 31784,
#                              'totalDamageTaken': 23021,
#                              'totalHeal': 3830,
#                              'totalMinionsKilled': 268,
#                              'totalPlayerScore': 0,
#                              'totalScoreRank': 0,
#                              'totalTimeCrowdControlDealt': 230,
#                              'totalUnitsHealed': 1,
#                              'tripleKills': 0,
#                              'trueDamageDealt': 17370,
#                              'trueDamageDealtToChampions': 9633,
#                              'trueDamageTaken': 1690,
#                              'turretKills': 0,
#                              'unrealKills': 0,
#                              'visionScore': 28,
#                              'visionWardsBoughtInGame': 1,
#                              'wardsKilled': 4,
#                              'wardsPlaced': 11,
#                              'win': True},
#                    'teamId': 100,
#                    'timeline': {'creepsPerMinDeltas': {'0-10': 5.8,
#                                                        '10-20': 8.7,
#                                                        '20-30': 8.7,
#                                                        '30-end': 6.4},
#                                 'csDiffPerMinDeltas': {'0-10': -0.40000000000000036,
#                                                        '10-20': 2.4,
#                                                        '20-30': 3.4,
#                                                        '30-end': -2},
#                                 'damageTakenDiffPerMinDeltas': {'0-10': -21.599999999999994,
#                                                                 '10-20': -401.6,
#                                                                 '20-30': -148.4000000000001,
#                                                                 '30-end': -47.00000000000006},
#                                 'damageTakenPerMinDeltas': {'0-10': 305.4,
#                                                             '10-20': 427.7,
#                                                             '20-30': 953.3,
#                                                             '30-end': 505.2},
#                                 'goldPerMinDeltas': {'0-10': 235.89999999999998,
#                                                      '10-20': 441.6,
#                                                      '20-30': 505.4,
#                                                      '30-end': 381.4},
#                                 'lane': 'MIDDLE',
#                                 'participantId': 2,
#                                 'role': 'SOLO',
#                                 'xpDiffPerMinDeltas': {'0-10': -51.70000000000002,
#                                                        '10-20': -24.5,
#                                                        '20-30': 151.09999999999997,
#                                                        '30-end': -284.8},
#                                 'xpPerMinDeltas': {'0-10': 419.3,
#                                                    '10-20': 528,
#                                                    '20-30': 554.9,
#                                                    '30-end': 398.8}}},
#                   {'championId': 81,
#                    'highestAchievedSeasonTier': 'UNRANKED',
#                    'participantId': 3,
#                    'spell1Id': 4,
#                    'spell2Id': 7,
#                    'stats': {'assists': 17,
#                              'champLevel': 16,
#                              'combatPlayerScore': 0,
#                              'damageDealtToObjectives': 7930,
#                              'damageDealtToTurrets': 2751,
#                              'damageSelfMitigated': 6277,
#                              'deaths': 4,
#                              'doubleKills': 0,
#                              'firstBloodAssist': False,
#                              'firstBloodKill': False,
#                              'firstTowerAssist': False,
#                              'firstTowerKill': False,
#                              'goldEarned': 11887,
#                              'goldSpent': 10758,
#                              'inhibitorKills': 0,
#                              'item0': 1055,
#                              'item1': 3003,
#                              'item2': 3078,
#                              'item3': 3042,
#                              'item4': 3111,
#                              'item5': 0,
#                              'item6': 3340,
#                              'killingSprees': 1,
#                              'kills': 4,
#                              'largestCriticalStrike': 0,
#                              'largestKillingSpree': 2,
#                              'largestMultiKill': 1,
#                              'longestTimeSpentLiving': 694,
#                              'magicDamageDealt': 19775,
#                              'magicDamageDealtToChampions': 6146,
#                              'magicalDamageTaken': 8449,
#                              'neutralMinionsKilled': 14,
#                              'neutralMinionsKilledEnemyJungle': 0,
#                              'neutralMinionsKilledTeamJungle': 10,
#                              'objectivePlayerScore': 0,
#                              'participantId': 3,
#                              'pentaKills': 0,
#                              'perk0': 8359,
#                              'perk0Var1': 685,
#                              'perk0Var2': 29,
#                              'perk0Var3': 0,
#                              'perk1': 8304,
#                              'perk1Var1': 9,
#                              'perk1Var2': 0,
#                              'perk1Var3': 0,
#                              'perk2': 8321,
#                              'perk2Var1': 5,
#                              'perk2Var2': 0,
#                              'perk2Var3': 0,
#                              'perk3': 8347,
#                              'perk3Var1': 0,
#                              'perk3Var2': 0,
#                              'perk3Var3': 0,
#                              'perk4': 8226,
#                              'perk4Var1': 250,
#                              'perk4Var2': 1440,
#                              'perk4Var3': 0,
#                              'perk5': 8236,
#                              'perk5Var1': 28,
#                              'perk5Var2': 0,
#                              'perk5Var3': 0,
#                              'perkPrimaryStyle': 8300,
#                              'perkSubStyle': 8200,
#                              'physicalDamageDealt': 99160,
#                              'physicalDamageDealtToChampions': 14929,
#                              'physicalDamageTaken': 6051,
#                              'playerScore0': 0,
#                              'playerScore1': 0,
#                              'playerScore2': 0,
#                              'playerScore3': 0,
#                              'playerScore4': 0,
#                              'playerScore5': 0,
#                              'playerScore6': 0,
#                              'playerScore7': 0,
#                              'playerScore8': 0,
#                              'playerScore9': 0,
#                              'quadraKills': 0,
#                              'sightWardsBoughtInGame': 0,
#                              'timeCCingOthers': 0,
#                              'totalDamageDealt': 120684,
#                              'totalDamageDealtToChampions': 21165,
#                              'totalDamageTaken': 14810,
#                              'totalHeal': 3148,
#                              'totalMinionsKilled': 138,
#                              'totalPlayerScore': 0,
#                              'totalScoreRank': 0,
#                              'totalTimeCrowdControlDealt': 0,
#                              'totalUnitsHealed': 3,
#                              'tripleKills': 0,
#                              'trueDamageDealt': 1749,
#                              'trueDamageDealtToChampions': 90,
#                              'trueDamageTaken': 310,
#                              'turretKills': 0,
#                              'unrealKills': 0,
#                              'visionScore': 20,
#                              'visionWardsBoughtInGame': 1,
#                              'wardsKilled': 1,
#                              'wardsPlaced': 11,
#                              'win': True},
#                    'teamId': 100,
#                    'timeline': {'creepsPerMinDeltas': {'0-10': 3.9000000000000004,
#                                                        '10-20': 3.7,
#                                                        '20-30': 3.2,
#                                                        '30-end': 5.2},
#                                 'csDiffPerMinDeltas': {'0-10': -1.45,
#                                                        '10-20': -1.4000000000000001,
#                                                        '20-30': -1.1500000000000004,
#                                                        '30-end': 0.5},
#                                 'damageTakenDiffPerMinDeltas': {'0-10': -140.40000000000003,
#                                                                 '10-20': -14.350000000000051,
#                                                                 '20-30': -335.65,
#                                                                 '30-end': 351.79999999999995},
#                                 'damageTakenPerMinDeltas': {'0-10': 192.2,
#                                                             '10-20': 459.1,
#                                                             '20-30': 487.3,
#                                                             '30-end': 477.6},
#                                 'goldPerMinDeltas': {'0-10': 201.2,
#                                                      '10-20': 362,
#                                                      '20-30': 380,
#                                                      '30-end': 305.2},
#                                 'lane': 'BOTTOM',
#                                 'participantId': 3,
#                                 'role': 'DUO_CARRY',
#                                 'xpDiffPerMinDeltas': {'0-10': 1.4999999999999858,
#                                                        '10-20': -34.44999999999999,
#                                                        '20-30': 143.75,
#                                                        '30-end': -105.90000000000003},
#                                 'xpPerMinDeltas': {'0-10': 286.4,
#                                                    '10-20': 391.79999999999995,
#                                                    '20-30': 597.7,
#                                                    '30-end': 345.6}}},
#                   {'championId': 62,
#                    'highestAchievedSeasonTier': 'SILVER',
#                    'participantId': 4,
#                    'spell1Id': 14,
#                    'spell2Id': 4,
#                    'stats': {'assists': 9,
#                              'champLevel': 18,
#                              'combatPlayerScore': 0,
#                              'damageDealtToObjectives': 9071,
#                              'damageDealtToTurrets': 2492,
#                              'damageSelfMitigated': 17262,
#                              'deaths': 3,
#                              'doubleKills': 2,
#                              'firstBloodAssist': False,
#                              'firstBloodKill': False,
#                              'firstTowerAssist': False,
#                              'firstTowerKill': False,
#                              'goldEarned': 15914,
#                              'goldSpent': 13950,
#                              'inhibitorKills': 0,
#                              'item0': 3074,
#                              'item1': 3142,
#                              'item2': 3026,
#                              'item3': 0,
#                              'item4': 3071,
#                              'item5': 3111,
#                              'item6': 3363,
#                              'killingSprees': 3,
#                              'kills': 14,
#                              'largestCriticalStrike': 0,
#                              'largestKillingSpree': 8,
#                              'largestMultiKill': 2,
#                              'longestTimeSpentLiving': 916,
#                              'magicDamageDealt': 1277,
#                              'magicDamageDealtToChampions': 167,
#                              'magicalDamageTaken': 17219,
#                              'neutralMinionsKilled': 29,
#                              'neutralMinionsKilledEnemyJungle': 4,
#                              'neutralMinionsKilledTeamJungle': 16,
#                              'objectivePlayerScore': 0,
#                              'participantId': 4,
#                              'pentaKills': 0,
#                              'perk0': 8112,
#                              'perk0Var1': 1683,
#                              'perk0Var2': 0,
#                              'perk0Var3': 0,
#                              'perk1': 8143,
#                              'perk1Var1': 866,
#                              'perk1Var2': 0,
#                              'perk1Var3': 0,
#                              'perk2': 8138,
#                              'perk2Var1': 18,
#                              'perk2Var2': 0,
#                              'perk2Var3': 0,
#                              'perk3': 8105,
#                              'perk3Var1': 5,
#                              'perk3Var2': 0,
#                              'perk3Var3': 0,
#                              'perk4': 9111,
#                              'perk4Var1': 1537,
#                              'perk4Var2': 460,
#                              'perk4Var3': 0,
#                              'perk5': 8014,
#                              'perk5Var1': 606,
#                              'perk5Var2': 0,
#                              'perk5Var3': 0,
#                              'perkPrimaryStyle': 8100,
#                              'perkSubStyle': 8000,
#                              'physicalDamageDealt': 140831,
#                              'physicalDamageDealtToChampions': 23043,
#                              'physicalDamageTaken': 6973,
#                              'playerScore0': 0,
#                              'playerScore1': 0,
#                              'playerScore2': 0,
#                              'playerScore3': 0,
#                              'playerScore4': 0,
#                              'playerScore5': 0,
#                              'playerScore6': 0,
#                              'playerScore7': 0,
#                              'playerScore8': 0,
#                              'playerScore9': 0,
#                              'quadraKills': 0,
#                              'sightWardsBoughtInGame': 0,
#                              'timeCCingOthers': 14,
#                              'totalDamageDealt': 146772,
#                              'totalDamageDealtToChampions': 24890,
#                              'totalDamageTaken': 24786,
#                              'totalHeal': 5327,
#                              'totalMinionsKilled': 195,
#                              'totalPlayerScore': 0,
#                              'totalScoreRank': 0,
#                              'totalTimeCrowdControlDealt': 124,
#                              'totalUnitsHealed': 1,
#                              'tripleKills': 0,
#                              'trueDamageDealt': 4663,
#                              'trueDamageDealtToChampions': 1679,
#                              'trueDamageTaken': 594,
#                              'turretKills': 1,
#                              'unrealKills': 0,
#                              'visionScore': 22,
#                              'visionWardsBoughtInGame': 2,
#                              'wardsKilled': 2,
#                              'wardsPlaced': 12,
#                              'win': True},
#                    'teamId': 100,
#                    'timeline': {'creepsPerMinDeltas': {'0-10': 6.8,
#                                                        '10-20': 5.7,
#                                                        '20-30': 5.9,
#                                                        '30-end': 0.2},
#                                 'csDiffPerMinDeltas': {'0-10': 0,
#                                                        '10-20': -0.7999999999999998,
#                                                        '20-30': 0.10000000000000009,
#                                                        '30-end': -5.3999999999999995},
#                                 'damageTakenDiffPerMinDeltas': {'0-10': 108.70000000000002,
#                                                                 '10-20': 48.79999999999998,
#                                                                 '20-30': 293.59999999999997,
#                                                                 '30-end': 420.20000000000005},
#                                 'damageTakenPerMinDeltas': {'0-10': 266.6,
#                                                             '10-20': 468.9,
#                                                             '20-30': 1150.9,
#                                                             '30-end': 1020.6},
#                                 'goldPerMinDeltas': {'0-10': 234.8,
#                                                      '10-20': 467.7,
#                                                      '20-30': 548.1,
#                                                      '30-end': 323.8},
#                                 'lane': 'TOP',
#                                 'participantId': 4,
#                                 'role': 'SOLO',
#                                 'xpDiffPerMinDeltas': {'0-10': -6.900000000000034,
#                                                        '10-20': 26.599999999999966,
#                                                        '20-30': 195.29999999999998,
#                                                        '30-end': -180.2},
#                                 'xpPerMinDeltas': {'0-10': 422.4,
#                                                    '10-20': 524.0999999999999,
#                                                    '20-30': 646.9,
#                                                    '30-end': 381.2}}},
#                   {'championId': 77,
#                    'highestAchievedSeasonTier': 'UNRANKED',
#                    'participantId': 5,
#                    'spell1Id': 11,
#                    'spell2Id': 4,
#                    'stats': {'assists': 13,
#                              'champLevel': 16,
#                              'combatPlayerScore': 0,
#                              'damageDealtToObjectives': 2835,
#                              'damageDealtToTurrets': 126,
#                              'damageSelfMitigated': 23809,
#                              'deaths': 9,
#                              'doubleKills': 1,
#                              'firstBloodAssist': False,
#                              'firstBloodKill': False,
#                              'firstTowerAssist': False,
#                              'firstTowerKill': False,
#                              'goldEarned': 11228,
#                              'goldSpent': 10025,
#                              'inhibitorKills': 0,
#                              'item0': 1416,
#                              'item1': 3748,
#                              'item2': 3009,
#                              'item3': 1031,
#                              'item4': 1011,
#                              'item5': 3211,
#                              'item6': 3340,
#                              'killingSprees': 1,
#                              'kills': 3,
#                              'largestCriticalStrike': 0,
#                              'largestKillingSpree': 2,
#                              'largestMultiKill': 2,
#                              'longestTimeSpentLiving': 376,
#                              'magicDamageDealt': 3052,
#                              'magicDamageDealtToChampions': 0,
#                              'magicalDamageTaken': 21329,
#                              'neutralMinionsKilled': 138,
#                              'neutralMinionsKilledEnemyJungle': 8,
#                              'neutralMinionsKilledTeamJungle': 110,
#                              'objectivePlayerScore': 0,
#                              'participantId': 5,
#                              'pentaKills': 0,
#                              'perk0': 8021,
#                              'perk0Var1': 2453,
#                              'perk0Var2': 0,
#                              'perk0Var3': 0,
#                              'perk1': 9111,
#                              'perk1Var1': 1083,
#                              'perk1Var2': 320,
#                              'perk1Var3': 0,
#                              'perk2': 9105,
#                              'perk2Var1': 16,
#                              'perk2Var2': 10,
#                              'perk2Var3': 0,
#                              'perk3': 8014,
#                              'perk3Var1': 319,
#                              'perk3Var2': 0,
#                              'perk3Var3': 0,
#                              'perk4': 8347,
#                              'perk4Var1': 0,
#                              'perk4Var2': 0,
#                              'perk4Var3': 0,
#                              'perk5': 8321,
#                              'perk5Var1': 9,
#                              'perk5Var2': 0,
#                              'perk5Var3': 0,
#                              'perkPrimaryStyle': 8000,
#                              'perkSubStyle': 8300,
#                              'physicalDamageDealt': 137269,
#                              'physicalDamageDealtToChampions': 14340,
#                              'physicalDamageTaken': 16671,
#                              'playerScore0': 0,
#                              'playerScore1': 0,
#                              'playerScore2': 0,
#                              'playerScore3': 0,
#                              'playerScore4': 0,
#                              'playerScore5': 0,
#                              'playerScore6': 0,
#                              'playerScore7': 0,
#                              'playerScore8': 0,
#                              'playerScore9': 0,
#                              'quadraKills': 0,
#                              'sightWardsBoughtInGame': 0,
#                              'timeCCingOthers': 40,
#                              'totalDamageDealt': 146051,
#                              'totalDamageDealtToChampions': 16462,
#                              'totalDamageTaken': 38916,
#                              'totalHeal': 12287,
#                              'totalMinionsKilled': 22,
#                              'totalPlayerScore': 0,
#                              'totalScoreRank': 0,
#                              'totalTimeCrowdControlDealt': 370,
#                              'totalUnitsHealed': 1,
#                              'tripleKills': 0,
#                              'trueDamageDealt': 5730,
#                              'trueDamageDealtToChampions': 2122,
#                              'trueDamageTaken': 915,
#                              'turretKills': 0,
#                              'unrealKills': 0,
#                              'visionScore': 37,
#                              'visionWardsBoughtInGame': 0,
#                              'wardsKilled': 3,
#                              'wardsPlaced': 13,
#                              'win': True},
#                    'teamId': 100,
#                    'timeline': {'creepsPerMinDeltas': {'0-10': 0,
#                                                        '10-20': 0.3,
#                                                        '20-30': 0.8999999999999999,
#                                                        '30-end': 1.8},
#                                 'csDiffPerMinDeltas': {'0-10': -0.2,
#                                                        '10-20': -0.7,
#                                                        '20-30': -1,
#                                                        '30-end': -0.9999999999999998},
#                                 'damageTakenDiffPerMinDeltas': {'0-10': 82.20000000000002,
#                                                                 '10-20': 173.89999999999992,
#                                                                 '20-30': 217.39999999999998,
#                                                                 '30-end': 300.80000000000007},
#                                 'damageTakenPerMinDeltas': {'0-10': 562.7,
#                                                             '10-20': 1114.6,
#                                                             '20-30': 1470.9,
#                                                             '30-end': 1254.2},
#                                 'goldPerMinDeltas': {'0-10': 292,
#                                                      '10-20': 273.2,
#                                                      '20-30': 322.2,
#                                                      '30-end': 298.6},
#                                 'lane': 'JUNGLE',
#                                 'participantId': 5,
#                                 'role': 'NONE',
#                                 'xpDiffPerMinDeltas': {'0-10': -5.400000000000006,
#                                                        '10-20': 32.5,
#                                                        '20-30': -45.39999999999998,
#                                                        '30-end': 148.2},
#                                 'xpPerMinDeltas': {'0-10': 305.7,
#                                                    '10-20': 414.5,
#                                                    '20-30': 474.1,
#                                                    '30-end': 464.4}}},
#                   {'championId': 222,
#                    'highestAchievedSeasonTier': 'BRONZE',
#                    'participantId': 6,
#                    'spell1Id': 7,
#                    'spell2Id': 4,
#                    'stats': {'assists': 10,
#                              'champLevel': 15,
#                              'combatPlayerScore': 0,
#                              'damageDealtToObjectives': 10115,
#                              'damageDealtToTurrets': 6496,
#                              'damageSelfMitigated': 10480,
#                              'deaths': 8,
#                              'doubleKills': 1,
#                              'firstBloodAssist': False,
#                              'firstBloodKill': False,
#                              'firstTowerAssist': False,
#                              'firstTowerKill': False,
#                              'goldEarned': 14067,
#                              'goldSpent': 13125,
#                              'inhibitorKills': 0,
#                              'item0': 3072,
#                              'item1': 1037,
#                              'item2': 3035,
#                              'item3': 3085,
#                              'item4': 3006,
#                              'item5': 3095,
#                              'item6': 3363,
#                              'killingSprees': 2,
#                              'kills': 5,
#                              'largestCriticalStrike': 854,
#                              'largestKillingSpree': 2,
#                              'largestMultiKill': 2,
#                              'longestTimeSpentLiving': 841,
#                              'magicDamageDealt': 676,
#                              'magicDamageDealtToChampions': 326,
#                              'magicalDamageTaken': 3344,
#                              'neutralMinionsKilled': 19,
#                              'neutralMinionsKilledEnemyJungle': 3,
#                              'neutralMinionsKilledTeamJungle': 12,
#                              'objectivePlayerScore': 0,
#                              'participantId': 6,
#                              'pentaKills': 0,
#                              'perk0': 8021,
#                              'perk0Var1': 1091,
#                              'perk0Var2': 0,
#                              'perk0Var3': 0,
#                              'perk1': 9111,
#                              'perk1Var1': 380,
#                              'perk1Var2': 300,
#                              'perk1Var3': 0,
#                              'perk2': 9104,
#                              'perk2Var1': 14,
#                              'perk2Var2': 50,
#                              'perk2Var3': 0,
#                              'perk3': 8014,
#                              'perk3Var1': 314,
#                              'perk3Var2': 0,
#                              'perk3Var3': 0,
#                              'perk4': 8234,
#                              'perk4Var1': 45,
#                              'perk4Var2': 0,
# ...
#                              'firstBloodKill': False,
#                              'firstTowerAssist': True,
#                              'firstTowerKill': False,
#                              'goldEarned': 8889,
#                              'goldSpent': 8200,
#                              'inhibitorKills': 0,
#                              'item0': 1001,
#                              'item1': 3143,
#                              'item2': 3401,
#                              'item3': 3075,
#                              'item4': 0,
#                              'item5': 0,
#                              'item6': 3364,
#                              'killingSprees': 1,
#                              'kills': 3,
#                              'largestCriticalStrike': 26,
#                              'largestKillingSpree': 3,
#                              'largestMultiKill': 1,
#                              'longestTimeSpentLiving': 677,
#                              'magicDamageDealt': 12674,
#                              'magicDamageDealtToChampions': 6814,
#                              'magicalDamageTaken': 5038,
#                              'neutralMinionsKilled': 0,
#                              'neutralMinionsKilledEnemyJungle': 0,
#                              'neutralMinionsKilledTeamJungle': 0,
#                              'objectivePlayerScore': 0,
#                              'participantId': 9,
#                              'pentaKills': 0,
#                              'perk0': 8437,
#                              'perk0Var1': 682,
#                              'perk0Var2': 559,
#                              'perk0Var3': 0,
#                              'perk1': 8473,
#                              'perk1Var1': 560,
#                              'perk1Var2': 0,
#                              'perk1Var3': 0,
#                              'perk2': 8444,
#                              'perk2Var1': 1762,
#                              'perk2Var2': 0,
#                              'perk2Var3': 0,
#                              'perk3': 8451,
#                              'perk3Var1': 218,
#                              'perk3Var2': 0,
#                              'perk3Var3': 0,
#                              'perk4': 8224,
#                              'perk4Var1': 441,
#                              'perk4Var2': 0,
#                              'perk4Var3': 0,
#                              'perk5': 8237,
#                              'perk5Var1': 307,
#                              'perk5Var2': 0,
#                              'perk5Var3': 0,
#                              'perkPrimaryStyle': 8400,
#                              'perkSubStyle': 8200,
#                              'physicalDamageDealt': 9923,
#                              'physicalDamageDealtToChampions': 1627,
#                              'physicalDamageTaken': 26005,
#                              'playerScore0': 0,
#                              'playerScore1': 0,
#                              'playerScore2': 0,
#                              'playerScore3': 0,
#                              'playerScore4': 0,
#                              'playerScore5': 0,
#                              'playerScore6': 0,
#                              'playerScore7': 0,
#                              'playerScore8': 0,
#                              'playerScore9': 0,
#                              'quadraKills': 0,
#                              'sightWardsBoughtInGame': 0,
#                              'timeCCingOthers': 45,
#                              'totalDamageDealt': 39441,
#                              'totalDamageDealtToChampions': 10258,
#                              'totalDamageTaken': 36582,
#                              'totalHeal': 9050,
#                              'totalMinionsKilled': 60,
#                              'totalPlayerScore': 0,
#                              'totalScoreRank': 0,
#                              'totalTimeCrowdControlDealt': 348,
#                              'totalUnitsHealed': 5,
#                              'tripleKills': 0,
#                              'trueDamageDealt': 16844,
#                              'trueDamageDealtToChampions': 1815,
#                              'trueDamageTaken': 5538,
#                              'turretKills': 0,
#                              'unrealKills': 0,
#                              'visionScore': 59,
#                              'visionWardsBoughtInGame': 0,
#                              'wardsKilled': 3,
#                              'wardsPlaced': 29,
#                              'win': False},
#                    'teamId': 200,
#                    'timeline': {'creepsPerMinDeltas': {'0-10': 1.3,
#                                                        '10-20': 1.8,
#                                                        '20-30': 2,
#                                                        '30-end': 1.6},
#                                 'csDiffPerMinDeltas': {'0-10': 1.45,
#                                                        '10-20': 1.4000000000000001,
#                                                        '20-30': 1.1500000000000004,
#                                                        '30-end': -0.5},
#                                 'damageTakenDiffPerMinDeltas': {'0-10': 140.40000000000003,
#                                                                 '10-20': 14.350000000000051,
#                                                                 '20-30': 335.65,
#                                                                 '30-end': -351.79999999999995},
#                                 'damageTakenPerMinDeltas': {'0-10': 457.6,
#                                                             '10-20': 968.7,
#                                                             '20-30': 1396.9,
#                                                             '30-end': 941.6},
#                                 'goldPerMinDeltas': {'0-10': 214.2,
#                                                      '10-20': 283.9,
#                                                      '20-30': 225.8,
#                                                      '30-end': 200.4},
#                                 'lane': 'BOTTOM',
#                                 'participantId': 9,
#                                 'role': 'DUO_SUPPORT',
#                                 'xpDiffPerMinDeltas': {'0-10': -1.4999999999999858,
#                                                        '10-20': 34.44999999999999,
#                                                        '20-30': -143.75,
#                                                        '30-end': 105.90000000000003},
#                                 'xpPerMinDeltas': {'0-10': 270.8,
#                                                    '10-20': 338.79999999999995,
#                                                    '20-30': 263.7,
#                                                    '30-end': 482}}},
#                   {'championId': 13,
#                    'highestAchievedSeasonTier': 'UNRANKED',
#                    'participantId': 10,
#                    'spell1Id': 12,
#                    'spell2Id': 4,
#                    'stats': {'assists': 5,
#                              'champLevel': 17,
#                              'combatPlayerScore': 0,
#                              'damageDealtToObjectives': 6324,
#                              'damageDealtToTurrets': 1035,
#                              'damageSelfMitigated': 20199,
#                              'deaths': 6,
#                              'doubleKills': 0,
#                              'firstBloodAssist': False,
#                              'firstBloodKill': True,
#                              'firstTowerAssist': False,
#                              'firstTowerKill': False,
#                              'goldEarned': 12061,
#                              'goldSpent': 10925,
#                              'inhibitorKills': 0,
#                              'item0': 3040,
#                              'item1': 3157,
#                              'item2': 2033,
#                              'item3': 3047,
#                              'item4': 3102,
#                              'item5': 0,
#                              'item6': 3363,
#                              'killingSprees': 0,
#                              'kills': 3,
#                              'largestCriticalStrike': 0,
#                              'largestKillingSpree': 0,
#                              'largestMultiKill': 1,
#                              'longestTimeSpentLiving': 634,
#                              'magicDamageDealt': 186168,
#                              'magicDamageDealtToChampions': 15803,
#                              'magicalDamageTaken': 3370,
#                              'neutralMinionsKilled': 32,
#                              'neutralMinionsKilledEnemyJungle': 4,
#                              'neutralMinionsKilledTeamJungle': 23,
#                              'objectivePlayerScore': 0,
#                              'participantId': 10,
#                              'pentaKills': 0,
#                              'perk0': 8230,
#                              'perk0Var1': 10,
#                              'perk0Var2': 0,
#                              'perk0Var3': 0,
#                              'perk1': 8226,
#                              'perk1Var1': 250,
#                              'perk1Var2': 1773,
#                              'perk1Var3': 0,
#                              'perk2': 8234,
#                              'perk2Var1': 23,
#                              'perk2Var2': 0,
#                              'perk2Var3': 0,
#                              'perk3': 8237,
#                              'perk3Var1': 346,
#                              'perk3Var2': 0,
#                              'perk3Var3': 0,
#                              'perk4': 8473,
#                              'perk4Var1': 696,
#                              'perk4Var2': 0,
#                              'perk4Var3': 0,
#                              'perk5': 8472,
#                              'perk5Var1': 0,
#                              'perk5Var2': 0,
#                              'perk5Var3': 0,
#                              'perkPrimaryStyle': 8200,
#                              'perkSubStyle': 8400,
#                              'physicalDamageDealt': 14850,
#                              'physicalDamageDealtToChampions': 448,
#                              'physicalDamageTaken': 14973,
#                              'playerScore0': 0,
#                              'playerScore1': 0,
#                              'playerScore2': 0,
#                              'playerScore3': 0,
#                              'playerScore4': 0,
#                              'playerScore5': 0,
#                              'playerScore6': 0,
#                              'playerScore7': 0,
#                              'playerScore8': 0,
#                              'playerScore9': 0,
#                              'quadraKills': 0,
#                              'sightWardsBoughtInGame': 0,
#                              'timeCCingOthers': 18,
#                              'totalDamageDealt': 203906,
#                              'totalDamageDealtToChampions': 16251,
#                              'totalDamageTaken': 19982,
#                              'totalHeal': 2361,
#                              'totalMinionsKilled': 220,
#                              'totalPlayerScore': 0,
#                              'totalScoreRank': 0,
#                              'totalTimeCrowdControlDealt': 48,
#                              'totalUnitsHealed': 1,
#                              'tripleKills': 0,
#                              'trueDamageDealt': 2887,
#                              'trueDamageDealtToChampions': 0,
#                              'trueDamageTaken': 1639,
#                              'turretKills': 1,
#                              'unrealKills': 0,
#                              'visionScore': 43,
#                              'visionWardsBoughtInGame': 3,
#                              'wardsKilled': 4,
#                              'wardsPlaced': 14,
#                              'win': False},
#                    'teamId': 200,
#                    'timeline': {'creepsPerMinDeltas': {'0-10': 6.8,
#                                                        '10-20': 6.5,
#                                                        '20-30': 5.8,
#                                                        '30-end': 5.6},
#                                 'csDiffPerMinDeltas': {'0-10': 0,
#                                                        '10-20': 0.7999999999999998,
#                                                        '20-30': -0.10000000000000009,
#                                                        '30-end': 5.3999999999999995},
#                                 'damageTakenDiffPerMinDeltas': {'0-10': -108.70000000000002,
#                                                                 '10-20': -48.79999999999998,
#                                                                 '20-30': -293.59999999999997,
#                                                                 '30-end': -420.20000000000005},
#                                 'damageTakenPerMinDeltas': {'0-10': 157.89999999999998,
#                                                             '10-20': 420.1,
#                                                             '20-30': 857.3,
#                                                             '30-end': 600.4},
#                                 'goldPerMinDeltas': {'0-10': 279.7,
#                                                      '10-20': 346.3,
#                                                      '20-30': 325.5,
#                                                      '30-end': 360.4},
#                                 'lane': 'TOP',
#                                 'participantId': 10,
#                                 'role': 'SOLO',
#                                 'xpDiffPerMinDeltas': {'0-10': 6.900000000000034,
#                                                        '10-20': -26.599999999999966,
#                                                        '20-30': -195.29999999999998,
#                                                        '30-end': 180.2},
#                                 'xpPerMinDeltas': {'0-10': 429.3,
#                                                    '10-20': 497.5,
#                                                    '20-30': 451.6,
#                                                    '30-end': 561.4}}}],
#  'platformId': 'KR',
#  'queueId': 420,
#  'seasonId': 11,
#  'teams': [{'bans': [{'championId': 64, 'pickTurn': 1},
#                      {'championId': 86, 'pickTurn': 2},
#                      {'championId': 21, 'pickTurn': 3},
#                      {'championId': 91, 'pickTurn': 4},
#                      {'championId': 122, 'pickTurn': 5}],
#             'baronKills': 0,
#             'dominionVictoryScore': 0,
#             'dragonKills': 0,
#             'firstBaron': False,
#             'firstBlood': False,
#             'firstDragon': False,
#             'firstInhibitor': False,
#             'firstRiftHerald': False,
#             'firstTower': False,
#             'inhibitorKills': 0,
#             'riftHeraldKills': 0,
#             'teamId': 100,
#             'towerKills': 3,
#             'vilemawKills': 0,
#             'win': 'Win'},
#            {'bans': [{'championId': 105, 'pickTurn': 6},
#                      {'championId': 89, 'pickTurn': 7},
#                      {'championId': 122, 'pickTurn': 8},
#                      {'championId': 91, 'pickTurn': 9},
#                      {'championId': 497, 'pickTurn': 10}],
#             'baronKills': 0,
#             'dominionVictoryScore': 0,
#             'dragonKills': 4,
#             'firstBaron': False,
#             'firstBlood': True,
#             'firstDragon': True,
#             'firstInhibitor': False,
#             'firstRiftHerald': True,
#             'firstTower': True,
#             'inhibitorKills': 0,
#             'riftHeraldKills': 1,
#             'teamId': 200,
#             'towerKills': 4,
#             'vilemawKills': 0,
#             'win': 'Fail'}]}

# %% [markdown]
# # Static Data
# static data documnetation: https://developer.riotgames.com/static-data.html#languages
#
# cf) dictionary를 리스트로 바꾸기
# dictionary에 .values() 적용하면 'dict_values'라는 형태의 자료형 반환. 이를 실제 리스트처럼 접근하기 위해서는 list(dict.values())로 명시적인 형변환 해줘야

# %%
# 영웅번호(string): 영웅이름(한글) 으로 된 dictionary 반환
def get_champion_json():
    api_data = requests.get("http://ddragon.leagueoflegends.com/cdn/6.24.1/data/ko_KR/champion.json")
    json_data = json.loads(api_data.content.decode("utf-8"))
    
    champion_list = list(json_data['data'].values())
    champion_dict = { champ['key']:champ['name'] for champ in champion_list}
    champion_dict['142'] = '조이'

    return champion_dict

# key: 아이템번호
# value: 'name', 'description', 'colloq', 'plaintext', 'into', 'image', 'gold', 'tags', 'maps', 'stats'를 key로 하는 dictionary
# 'map': {'1': False,'8': True, '10': True, ... } 이런 식으로 각 맵에서 지원이 되는지 여부
def get_item_json(): 
    api_data = requests.get("http://ddragon.leagueoflegends.com/cdn/6.24.1/data/ko_KR/item.json")
    json_data = json.loads(api_data.content.decode("utf-8"))
    return json_data['data']

def get_profile_icons_json(): 
    api_data = requests.get("http://ddragon.leagueoflegends.com/cdn/6.24.1/data/ko_KR/profileicon.json")
    json_data = json.loads(api_data.content.decode("utf-8"))
    return json_data['data']
    
def get_individual_champions(champion):
    api_data = requests.get("http://ddragon.leagueoflegends.com/cdn/6.24.1/data/ko_KR/champion/%s.json" % champion)
    json_data = json.loads(api_data.content.decode("utf-8"))
    return json_data['data']

def get_masteries():
    api_data = requests.get("http://ddragon.leagueoflegends.com/cdn/6.24.1/data/ko_KR/mastery.json")
    json_data = json.loads(api_data.content.decode("utf-8"))
    return json_data['data']

def get_runes():
    api_data = requests.get("http://ddragon.leagueoflegends.com/cdn/6.24.1/data/en_US/rune.json")
    json_data = json.loads(api_data.content.decode("utf-8"))  
    return json_data['data']

def get_summoner_spells():
    api_data = requests.get("http://ddragon.leagueoflegends.com/cdn/6.24.1/data/ko_KR/summoner.json")
    json_data = json.loads(api_data.content.decode("utf-8"))
    return json_data['data']
    
# get_summoner_spells()
get_item_json()
# Out:
# {'1001': {'name': '속도의 장화',
#   'description': '<groupLimit>1개만 구입 가능합니다.</groupLimit><br><br><unique>고유 지속 효과 - 이동 속도 향상:</unique> 이동 속도 +25',
#   'colloq': ';똥신;boots;speed',
#   'plaintext': '이동 속도가 약간 증가합니다.',
#   'into': ['3006', '3047', '3020', '3158', '3111', '3117', '3009'],
#   'image': {'full': '1001.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 0,
#    'y': 0,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 300, 'purchasable': True, 'total': 300, 'sell': 210},
#   'tags': ['Boots'],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {'FlatMovementSpeedMod': 25.0}},
#  '1004': {'name': '요정의 부적',
#   'description': '<stats><mana>기본 마나 재생 +25% </mana></stats>',
#   'colloq': ';요부;faerie;charm',
#   'plaintext': '마나 재생량이 약간 증가합니다.',
#   'into': ['3028', '3070', '3073', '3098', '3096', '3114'],
#   'image': {'full': '1004.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 48,
#    'y': 0,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 125, 'purchasable': True, 'total': 125, 'sell': 88},
#   'tags': ['ManaRegen'],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {}},
#  '1006': {'name': '원기 회복의 구슬',
#   'description': '<stats>기본 체력 재생 +50% </stats>',
#   'colloq': ';완두콩;rejuvenation;bead',
#   'plaintext': '체력 재생량이 약간 증가합니다.',
#   'into': ['3077', '2053', '3097', '3801'],
#   'image': {'full': '1006.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 96,
#    'y': 0,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 150, 'purchasable': True, 'total': 150, 'sell': 105},
#   'tags': ['HealthRegen'],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {}},
#  '1011': {'name': '거인의 허리띠',
#   'description': '<stats>체력 +380</stats>',
#   'colloq': ';자벨;giant;belt',
#   'plaintext': '체력이 대폭 증가합니다.',
#   'from': ['1028'],
#   'into': ['3083', '3143', '3116', '3084', '3022', '3742'],
#   'image': {'full': '1011.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 144,
#    'y': 0,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 600, 'purchasable': True, 'total': 1000, 'sell': 700},
#   'tags': ['Health'],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {'FlatHPPoolMod': 380.0},
#   'depth': 2},
#  '1018': {'name': '민첩성의 망토',
#   'description': '<stats>치명타 확률 +20%</stats>',
#   'colloq': ';cloak;agility',
#   'plaintext': '치명타 확률이 증가합니다.',
#   'into': ['3031', '3185', '3508'],
#   'image': {'full': '1018.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 192,
#    'y': 0,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 800, 'purchasable': True, 'total': 800, 'sell': 560},
#   'tags': ['CriticalStrike'],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {'FlatCritChanceMod': 0.2}},
#  '1026': {'name': '방출의 마법봉',
#   'description': '<stats>주문력 +40</stats>',
#   'colloq': ';blasting;wand',
#   'plaintext': '주문력이 상당히 상승합니다.',
#   'into': ['3089', '3135', '3124', '3029', '3027', '3100', '3116', '3151'],
#   'image': {'full': '1026.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 240,
#    'y': 0,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 850, 'purchasable': True, 'total': 850, 'sell': 595},
#   'tags': ['SpellDamage'],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {'FlatMagicDamageMod': 40.0}},
#  '1027': {'name': '사파이어 수정',
#   'description': '<stats><mana>마나 +250</mana></stats>',
#   'colloq': ';sapphire;crystal;blue',
#   'plaintext': '마나가 증가합니다.',
#   'into': ['3057', '3070', '3010', '3024', '3073', '3802'],
#   'image': {'full': '1027.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 288,
#    'y': 0,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 350, 'purchasable': True, 'total': 350, 'sell': 245},
#   'tags': ['Mana'],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {'FlatMPPoolMod': 250.0}},
#  '1028': {'name': '루비 수정',
#   'description': '<stats>체력 +150</stats>',
#   'colloq': ';ruby;crystal;red',
#   'plaintext': '체력이 증가합니다.',
#   'into': ['1011',
#    '3751',
#    '2049',
#    '2045',
#    '3010',
#    '3052',
#    '3044',
#    '3067',
#    '3211',
#    '3801',
#    '3116',
#    '3136',
#    '3748'],
#   'image': {'full': '1028.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 336,
#    'y': 0,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 400, 'purchasable': True, 'total': 400, 'sell': 280},
#   'tags': ['Health'],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {'FlatHPPoolMod': 150.0}},
#  '1029': {'name': '천 갑옷',
#   'description': '<stats>방어력 +15</stats>',
#   'colloq': ';300;300갑;천갑;cloth;armor',
#   'plaintext': '방어력이 약간 증가합니다.',
#   'into': ['3047',
#    '1031',
#    '3191',
#    '3024',
#    '3082',
#    '3075',
#    '2053',
#    '3105',
#    '3109'],
#   'image': {'full': '1029.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 384,
#    'y': 0,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 300, 'purchasable': True, 'total': 300, 'sell': 210},
#   'tags': ['Armor'],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {'FlatArmorMod': 15.0}},
#  '1031': {'name': '쇠사슬 조끼',
#   'description': '<stats>방어력 +40</stats>',
#   'colloq': ';700;700갑;chain;vest',
#   'plaintext': '방어력이 대폭 증가합니다.',
#   'from': ['1029'],
#   'into': ['3075', '3068', '3026', '2053', '3742'],
#   'image': {'full': '1031.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 432,
#    'y': 0,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 500, 'purchasable': True, 'total': 800, 'sell': 560},
#   'tags': ['Armor'],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {'FlatArmorMod': 40.0},
#   'depth': 2},
#  '1033': {'name': '마법무효화의 망토',
#   'description': '<stats>마법 저항력 +25</stats>',
#   'colloq': ';null;magic;mantle',
#   'plaintext': '마법 저항력이 약간 증가합니다.',
#   'into': ['3111',
#    '3211',
#    '1057',
#    '3028',
#    '3140',
#    '3155',
#    '3105',
#    '3190',
#    '3814'],
#   'image': {'full': '1033.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 0,
#    'y': 48,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 450, 'purchasable': True, 'total': 450, 'sell': 315},
#   'tags': ['SpellBlock'],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {'FlatSpellBlockMod': 25.0}},
#  '1036': {'name': '롱소드',
#   'description': '<stats>공격력 +10</stats>',
#   'colloq': ';long;sword',
#   'plaintext': '공격력이 약간 증가합니다.',
#   'into': ['1053',
#    '3133',
#    '3052',
#    '3123',
#    '3034',
#    '3044',
#    '3053',
#    '3072',
#    '3077',
#    '3122',
#    '3134',
#    '3144',
#    '3155',
#    '3252'],
#   'image': {'full': '1036.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 48,
#    'y': 48,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 350, 'purchasable': True, 'total': 350, 'sell': 245},
#   'tags': ['Damage', 'Lane'],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {'FlatPhysicalDamageMod': 10.0}},
#  '1037': {'name': '곡괭이',
#   'description': '<stats>공격력 +25</stats>',
#   'colloq': ';pick;axe;pickaxe',
#   'plaintext': '공격력이 상당히 증가합니다.',
#   'into': ['3004',
#    '3008',
#    '3031',
#    '3035',
#    '3074',
#    '3124',
#    '3139',
#    '3181',
#    '3812',
#    '3814'],
#   'image': {'full': '1037.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 96,
#    'y': 48,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 875, 'purchasable': True, 'total': 875, 'sell': 613},
#   'tags': ['Damage'],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {'FlatPhysicalDamageMod': 25.0}},
#  '1038': {'name': 'B.F. 대검',
#   'description': '<stats>공격력 +40</stats>',
#   'colloq': ';bf;절친;sword',
#   'plaintext': '공격력이 대폭 증가합니다.',
#   'into': ['3031', '3072', '3147', '3508'],
#   'image': {'full': '1038.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 144,
#    'y': 48,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 1300, 'purchasable': True, 'total': 1300, 'sell': 910},
#   'tags': ['Damage'],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {'FlatPhysicalDamageMod': 40.0}},
#  '1039': {'name': '사냥꾼의 부적',
#   'description': "<stats><mana>정글에서 기본 마나 재생 +150% </mana></stats><br><br><unique>고유 지속 효과 - 이빨:</unique> 몬스터에게 스킬 혹은 공격으로 피해를 입히면 5초 동안 25의 체력을 흡수합니다. 몬스터 처치 시 <font color='#99BBBB'><a href='SpecialJungleExperience'>특별 추가 경험치</a></font>를 얻습니다.",
#   'colloq': ';jungle;Jungle;정글',
#   'plaintext': '정글에서 마나 재생을 돕고 몬스터에게 피해를 입힙니다.',
#   'into': ['3706', '3711', '3715'],
#   'image': {'full': '1039.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 192,
#    'y': 48,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 350, 'purchasable': True, 'total': 350, 'sell': 245},
#   'tags': ['Jungle', 'LifeSteal', 'ManaRegen', 'OnHit'],
#   'maps': {'1': False,
#    '8': False,
#    '10': True,
#    '11': True,
#    '12': False,
#    '14': False},
#   'stats': {},
#   'effect': {'Effect1Amount': '25',
#    'Effect2Amount': '0',
#    'Effect3Amount': '0',
#    'Effect4Amount': '5',
#    'Effect5Amount': '0',
#    'Effect6Amount': '1.5',
#    'Effect7Amount': '15'}},
#  '1041': {'name': '사냥꾼의 마체테',
#   'description': "<stats>몬스터 대상 생명력 흡수 +10%</stats><br><br><unique>고유 지속 효과 - 손톱:</unique> 몬스터에게 기본 공격 적중 시 추가로 25의 피해를 입힙니다. 몬스터 처치 시 <font color='#99BBBB'><a href='SpecialJungleExperience'>특별 추가 경험치</a></font>를 얻습니다.",
#   'colloq': ';정글;정글',
#   'plaintext': '몬스터 상대 공격력이 상승하고 생명력을 흡수합니다.',
#   'into': ['3706', '3711', '3715'],
#   'image': {'full': '1041.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 240,
#    'y': 48,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 350, 'purchasable': True, 'total': 350, 'sell': 245},
#   'tags': ['Jungle', 'LifeSteal', 'OnHit'],
#   'maps': {'1': False,
#    '8': False,
#    '10': True,
#    '11': True,
#    '12': False,
#    '14': False},
#   'stats': {},
#   'effect': {'Effect1Amount': '12',
#    'Effect2Amount': '25',
#    'Effect3Amount': '0.1',
#    'Effect4Amount': '2',
#    'Effect5Amount': '0',
#    'Effect6Amount': '0.1',
#    'Effect7Amount': '15'}},
#  '1042': {'name': '단검',
#   'description': '<stats>공격 속도 +12%</stats>',
#   'colloq': ';dagger',
#   'plaintext': '공격 속도가 약간 증가합니다.',
#   'into': ['1043', '2015', '3006', '3046', '3086', '3101', '3091'],
#   'image': {'full': '1042.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 288,
#    'y': 48,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 300, 'purchasable': True, 'total': 300, 'sell': 210},
#   'tags': ['AttackSpeed'],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {'PercentAttackSpeedMod': 0.12}},
#  '1043': {'name': '곡궁',
#   'description': '<stats>공격 속도 +25%</stats><br><br><unique>고유 지속 효과:</unique> 기본 공격 적중 시 추가 15의 물리 피해를 입힙니다.',
#   'colloq': ';공속활;고래;recurve;bow',
#   'plaintext': '공격 속도가 대폭 증가합니다.',
#   'from': ['1042', '1042'],
#   'into': ['3091',
#    '3153',
#    '3085',
#    '3718',
#    '3722',
#    '1416',
#    '1418',
#    '1419',
#    '3124',
#    '3675'],
#   'image': {'full': '1043.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 336,
#    'y': 48,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 400, 'purchasable': True, 'total': 1000, 'sell': 700},
#   'tags': ['AttackSpeed', 'OnHit'],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {'PercentAttackSpeedMod': 0.25},
#   'effect': {'Effect1Amount': '15'},
#   'depth': 2},
#  '1051': {'name': '싸움꾼의 장갑',
#   'description': '<stats>치명타 확률 +10%</stats>',
#   'colloq': ';brawlers;gloves',
#   'plaintext': '치명타 확률이 약간 증가합니다.',
#   'into': ['3086', '3122'],
#   'image': {'full': '1051.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 384,
#    'y': 48,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 400, 'purchasable': True, 'total': 400, 'sell': 280},
#   'tags': ['CriticalStrike'],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {'FlatCritChanceMod': 0.1}},
#  '1052': {'name': '증폭의 고서',
#   'description': '<stats>주문력 +20</stats>',
#   'colloq': ';책;amptome;amplifying;tome',
#   'plaintext': '주문력이 약간 상승합니다.',
#   'into': ['3108',
#    '3191',
#    '3136',
#    '3135',
#    '3145',
#    '3113',
#    '3090',
#    '3116',
#    '1402',
#    '1410',
#    '1414',
#    '3001',
#    '3050',
#    '3089',
#    '3165',
#    '3802',
#    '3673'],
#   'image': {'full': '1052.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 432,
#    'y': 48,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 435, 'purchasable': True, 'total': 435, 'sell': 305},
#   'tags': ['SpellDamage'],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {'FlatMagicDamageMod': 20.0}},
#  '1053': {'name': '흡혈의 낫',
#   'description': '<stats>공격력 +15<br>생명력 흡수 +10%</stats>',
#   'colloq': ';흡낫;vampiric;scepter',
#   'plaintext': '기본 공격 시 체력을 회복합니다.',
#   'from': ['1036'],
#   'into': ['3072', '3074', '3139', '3144', '3181', '3812'],
#   'image': {'full': '1053.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 0,
#    'y': 96,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 550, 'purchasable': True, 'total': 900, 'sell': 630},
#   'tags': ['Damage', 'LifeSteal'],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {'FlatPhysicalDamageMod': 15.0, 'PercentLifeStealMod': 0.1},
#   'depth': 2},
#  '1054': {'name': '도란의 방패',
#   'description': '<stats>체력 +80</stats><br><br><passive>기본 지속 효과:</passive> 5초마다 6의 체력을 회복합니다.<br><unique>고유 지속 효과:</unique> 적 챔피언의 단일 대상 공격과 스킬 공격 피해량을 8만큼 막아줍니다.',
#   'colloq': ';도란실드;doran;shield;dshield',
#   'plaintext': '방어에 특화된 시작 아이템입니다.',
#   'into': [],
#   'image': {'full': '1054.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 48,
#    'y': 96,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 450, 'purchasable': True, 'total': 450, 'sell': 180},
#   'tags': ['Health', 'HealthRegen', 'Lane'],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {'FlatHPPoolMod': 80.0, 'FlatHPRegenMod': 1.2},
#   'effect': {'Effect1Amount': '8'}},
#  '1055': {'name': '도란의 검',
#   'description': '<stats>공격력 +8<br>체력 +80<br>생명력 흡수 +3%</stats>',
#   'colloq': ';도란칼;doran;blade;dblade',
#   'plaintext': '공격에 특화된 시작 아이템입니다.',
#   'into': [],
#   'image': {'full': '1055.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 96,
#    'y': 96,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 450, 'purchasable': True, 'total': 450, 'sell': 180},
#   'tags': ['Damage', 'Health', 'Lane', 'LifeSteal'],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {'FlatHPPoolMod': 80.0,
#    'FlatPhysicalDamageMod': 8.0,
#    'PercentLifeStealMod': 0.03},
#   'effect': {'Effect1Amount': '10'}},
#  '1056': {'name': '도란의 반지',
#   'description': '<stats>체력 +60<br>주문력 +15<br><mana>기본 마나 재생 +50% </mana></stats><br><br><mana><passive>기본 지속 효과:</passive> 유닛 처치 시마다 4의 마나를 회복합니다.</mana>',
#   'colloq': ';도란링;doran;ring;dring',
#   'plaintext': '스킬 사용에 특화된 시작 아이템입니다.',
#   'into': [],
#   'image': {'full': '1056.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 144,
#    'y': 96,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 400, 'purchasable': True, 'total': 400, 'sell': 160},
#   'tags': ['Health', 'Lane', 'ManaRegen', 'SpellDamage'],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {'FlatHPPoolMod': 60.0, 'FlatMagicDamageMod': 15.0},
#   'effect': {'Effect1Amount': '4'}},
#  '1057': {'name': '음전자 망토',
#   'description': '<stats>마법 저항력 +40</stats>',
#   'colloq': ';조개;negatron;cloak',
#   'plaintext': '마법 저항력이 상당히 증가합니다.',
#   'from': ['1033'],
#   'into': ['3001', '3026', '3091', '3102', '3170', '3512'],
#   'image': {'full': '1057.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 192,
#    'y': 96,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 270, 'purchasable': True, 'total': 720, 'sell': 504},
#   'tags': ['SpellBlock'],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {'FlatSpellBlockMod': 40.0},
#   'depth': 2},
#  '1058': {'name': '쓸데없이 큰 지팡이',
#   'description': '<stats>주문력 +60</stats>',
#   'colloq': ';nlr;needlessly;large;rod',
#   'plaintext': '주문력이 대폭 상승합니다.',
#   'into': ['3089', '3003', '3007', '3090', '3285'],
#   'image': {'full': '1058.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 240,
#    'y': 96,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 1250, 'purchasable': True, 'total': 1250, 'sell': 875},
#   'tags': ['SpellDamage'],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {'FlatMagicDamageMod': 60.0}},
#  '1082': {'name': '암흑의 인장',
#   'description': '<stats>주문력 +15<br>물약 회복량 증가 +25%<br><mana>마나 +100</mana></stats><br><br><unique>고유 지속 효과 - 두려움:</unique> 영광 중첩 하나 당 주문력이 3만큼 상승합니다. <br><unique>고유 지속 효과 - 절체절명:</unique> 적 챔피언을 처치할 때마다 영광 중첩 2회, 어시스트를 올릴 때마다 영광 중첩 1회가 쌓이고 중첩은 최대 10회까지 쌓을 수 있습니다. 사망 시 중첩 4회가 사라집니다.',
#   'colloq': ';Noxian',
#   'plaintext': '주문력과 마나가 상승하며 적을 처치할 때마다 더욱 강력해집니다.',
#   'into': ['3041'],
#   'image': {'full': '1082.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 288,
#    'y': 96,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 350, 'purchasable': True, 'total': 350, 'sell': 245},
#   'tags': ['HealthRegen', 'Lane', 'Mana', 'SpellDamage'],
#   'maps': {'1': False,
#    '8': False,
#    '10': False,
#    '11': True,
#    '12': False,
#    '14': False},
#   'stats': {'FlatMPPoolMod': 100.0, 'FlatMagicDamageMod': 15.0},
#   'effect': {'Effect1Amount': '0.25',
#    'Effect2Amount': '2',
#    'Effect3Amount': '1',
#    'Effect4Amount': '10',
#    'Effect5Amount': '3',
#    'Effect6Amount': '4'}},
#  '1083': {'name': '수확의 낫',
#   'description': '<stats>공격력 +7<br>적중 시 생명력 흡수 +3</stats><br><br><unique>고유 지속 효과:</unique> 공격로 미니언 처치 시 추가로 1 골드를 얻습니다. 공격로 미니언을 총 100회 처치하면 즉시 350의 추가 골드를 얻고 기본 지속 효과가 비활성화됩니다.',
#   'colloq': ';도란칼',
#   'plaintext': '피해를 입히고 적중 시 생명력을 흡수합니다. 미니언 처치 시 추가 골드를 얻습니다.',
#   'into': [],
#   'image': {'full': '1083.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 336,
#    'y': 96,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 450, 'purchasable': True, 'total': 450, 'sell': 180},
#   'tags': ['Damage', 'Lane', 'LifeSteal'],
#   'maps': {'1': False,
#    '8': False,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {'FlatPhysicalDamageMod': 7.0},
#   'effect': {'Effect1Amount': '3',
#    'Effect2Amount': '1',
#    'Effect3Amount': '100',
#    'Effect4Amount': '350'}},
#  '1400': {'name': '마법 부여: 용사',
#   'description': '<stats>공격력 +60<br>재사용 대기시간 감소 +10%</stats>',
#   'colloq': ';',
#   'plaintext': '공격력이 증가하고 재사용 대기시간이 감소합니다.',
#   'from': ['3133', '3706'],
#   'hideFromAll': True,
#   'into': [],
#   'image': {'full': '1400.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 384,
#    'y': 96,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 525, 'purchasable': True, 'total': 2625, 'sell': 1837},
#   'tags': [],
#   'maps': {'1': False,
#    '8': False,
#    '10': True,
#    '11': True,
#    '12': False,
#    '14': False},
#   'stats': {'FlatPhysicalDamageMod': 60.0},
#   'effect': {'Effect1Amount': '30',
#    'Effect2Amount': '25',
#    'Effect3Amount': '1.8',
#    'Effect4Amount': '5',
#    'Effect5Amount': '30',
#    'Effect6Amount': '-0.2',
#    'Effect7Amount': '2',
#    'Effect8Amount': '3'},
#   'depth': 3},
#  '1401': {'name': '마법 부여: 잿불거인',
#   'description': '<stats>체력 +400<br>추가 체력 +15%</stats><br><br><unique>고유 지속 효과 - 불사르기:</unique> 전투 중일 때 근처 적에게 초당 7 (챔피언 레벨당 +2)의 마법 피해를 입힙니다. 몬스터에게는 100%의 추가 피해를 입힙니다. ',
#   'colloq': ';',
#   'plaintext': '체력과 불사르기 오오라를 부여합니다.',
#   'from': ['3751', '3706'],
#   'hideFromAll': True,
#   'into': [],
#   'image': {'full': '1401.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 432,
#    'y': 96,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 525, 'purchasable': True, 'total': 2625, 'sell': 1837},
#   'tags': [],
#   'maps': {'1': False,
#    '8': False,
#    '10': True,
#    '11': True,
#    '12': False,
#    '14': False},
#   'stats': {'FlatHPPoolMod': 400.0},
#   'effect': {'Effect1Amount': '30',
#    'Effect2Amount': '25',
#    'Effect3Amount': '1.8',
#    'Effect4Amount': '5',
#    'Effect5Amount': '30',
#    'Effect6Amount': '-0.2',
#    'Effect7Amount': '2',
#    'Effect8Amount': '3'},
#   'depth': 3},
#  '1402': {'name': '마법 부여: 룬의 메아리',
#   'description': '<stats>주문력 +60<br>이동 속도 +7% </stats><br><br><unique>고유 지속 효과 - 메아리:</unique> 이동하거나 스킬을 사용하면 중첩이 쌓입니다. 중첩이 100회 쌓이면 다음에 스킬로 피해를 입혔을 때 중첩을 모두 소모하여 최대 4명의 대상에게 60 (+ 주문력의 10%)의 추가 마법 피해를 입힙니다.<br><br> 대형 몬스터에게는 250%의 피해를 입히며, 이 효과가 대형 몬스터에게 적중하면 잃은 마나의 18%를 회복합니다.',
#   'colloq': ';',
#   'plaintext': '주문력이 증가하고 주기적으로 스킬이 강화됩니다.',
#   'from': ['3113', '1052', '3706'],
#   'hideFromAll': True,
#   'into': [],
#   'image': {'full': '1402.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 0,
#    'y': 144,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 340, 'purchasable': True, 'total': 2625, 'sell': 1837},
#   'tags': [],
#   'maps': {'1': False,
#    '8': False,
#    '10': True,
#    '11': True,
#    '12': False,
#    '14': False},
#   'stats': {'FlatMagicDamageMod': 60.0, 'PercentMovementSpeedMod': 0.07},
#   'effect': {'Effect1Amount': '30',
#    'Effect2Amount': '25',
#    'Effect3Amount': '1.8',
#    'Effect4Amount': '5',
#    'Effect5Amount': '30',
#    'Effect6Amount': '-0.2',
#    'Effect7Amount': '2',
#    'Effect8Amount': '3'},
#   'depth': 3},
#  '1408': {'name': '마법 부여: 용사',
#   'description': '<stats>공격력 +60<br>재사용 대기시간 감소 +10%</stats>',
#   'colloq': ';',
#   'plaintext': '공격력이 증가하고 재사용 대기시간이 감소합니다.',
#   'from': ['3133', '3711'],
#   'hideFromAll': True,
#   'into': [],
#   'image': {'full': '1408.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 192,
#    'y': 144,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 525, 'purchasable': True, 'total': 2625, 'sell': 1837},
#   'tags': [],
#   'maps': {'1': False,
#    '8': False,
#    '10': False,
#    '11': True,
#    '12': False,
#    '14': False},
#   'stats': {'FlatPhysicalDamageMod': 60.0},
#   'effect': {'Effect1Amount': '30',
#    'Effect2Amount': '25',
#    'Effect3Amount': '1.8',
#    'Effect4Amount': '5',
#    'Effect5Amount': '30',
#    'Effect6Amount': '3',
#    'Effect7Amount': '20',
#    'Effect8Amount': '30'},
#   'depth': 3},
#  '1409': {'name': '마법 부여: 잿불거인',
#   'description': '<stats>체력 +400<br>추가 체력 +15%</stats><br><br><unique>고유 지속 효과 - 불사르기:</unique> 전투 중일 때 근처 적에게 초당 7 (챔피언 레벨당 +2)의 마법 피해를 입힙니다. 몬스터에게는 100%의 추가 피해를 입힙니다. ',
#   'colloq': ';',
#   'plaintext': '체력과 불사르기 오오라를 부여합니다.',
#   'from': ['3751', '3711'],
#   'hideFromAll': True,
#   'into': [],
#   'image': {'full': '1409.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 240,
#    'y': 144,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 525, 'purchasable': True, 'total': 2625, 'sell': 1837},
#   'tags': [],
#   'maps': {'1': False,
#    '8': False,
#    '10': False,
#    '11': True,
#    '12': False,
#    '14': False},
#   'stats': {'FlatHPPoolMod': 400.0},
#   'effect': {'Effect1Amount': '30',
#    'Effect2Amount': '25',
#    'Effect3Amount': '1.8',
#    'Effect4Amount': '5',
#    'Effect5Amount': '30',
#    'Effect6Amount': '3',
#    'Effect7Amount': '20',
#    'Effect8Amount': '30'},
#   'depth': 3},
#  '1410': {'name': '마법 부여: 룬의 메아리',
#   'description': '<stats>주문력 +60<br>이동 속도 +7% </stats><br><br><unique>고유 지속 효과 - 메아리:</unique> 이동하거나 스킬을 사용하면 중첩이 쌓입니다. 중첩이 100회 쌓이면 다음에 스킬로 피해를 입혔을 때 중첩을 모두 소모하여 최대 4명의 대상에게 60 (+ 주문력의 10%)의 추가 마법 피해를 입힙니다.<br><br> 대형 몬스터에게는 250%의 피해를 입히며, 이 효과가 대형 몬스터에게 적중하면 잃은 마나의 18%를 회복합니다.',
#   'colloq': ';',
#   'plaintext': '주문력이 증가하고 주기적으로 스킬이 강화됩니다.',
#   'from': ['3113', '1052', '3711'],
#   'hideFromAll': True,
#   'into': [],
#   'image': {'full': '1410.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 288,
#    'y': 144,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 340, 'purchasable': True, 'total': 2625, 'sell': 1837},
#   'tags': [],
#   'maps': {'1': False,
#    '8': False,
#    '10': False,
#    '11': True,
#    '12': False,
#    '14': False},
#   'stats': {'FlatMagicDamageMod': 60.0, 'PercentMovementSpeedMod': 0.07},
#   'effect': {'Effect1Amount': '30',
#    'Effect2Amount': '25',
#    'Effect3Amount': '1.8',
#    'Effect4Amount': '5',
#    'Effect5Amount': '30',
#    'Effect6Amount': '3',
#    'Effect7Amount': '20',
#    'Effect8Amount': '30'},
#   'depth': 3},
#  '1412': {'name': '마법 부여: 용사',
#   'description': '<stats>공격력 +60<br>재사용 대기시간 감소 +10%</stats>',
#   'colloq': ';',
#   'plaintext': '공격력이 증가하고 재사용 대기시간이 감소합니다.',
#   'from': ['3133', '3715'],
#   'hideFromAll': True,
#   'into': [],
#   'image': {'full': '1412.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 336,
#    'y': 144,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 525, 'purchasable': True, 'total': 2625, 'sell': 1837},
#   'tags': [],
#   'maps': {'1': False,
#    '8': False,
#    '10': True,
#    '11': True,
#    '12': False,
#    '14': False},
#   'stats': {'FlatPhysicalDamageMod': 60.0},
#   'effect': {'Effect1Amount': '30',
#    'Effect2Amount': '25',
#    'Effect3Amount': '1.8',
#    'Effect4Amount': '5',
#    'Effect5Amount': '30',
#    'Effect6Amount': '3',
#    'Effect7Amount': '20',
#    'Effect8Amount': '18'},
#   'depth': 3},
#  '1413': {'name': '마법 부여: 잿불거인',
#   'description': '<stats>체력 +400<br>추가 체력 +15%</stats><br><br><unique>고유 지속 효과 - 불사르기:</unique> 전투 중일 때 근처 적에게 초당 7 (챔피언 레벨당 +2)의 마법 피해를 입힙니다. 몬스터에게는 100%의 추가 피해를 입힙니다. ',
#   'colloq': ';',
#   'plaintext': '체력과 불사르기 오오라를 부여합니다.',
#   'from': ['3751', '3715'],
#   'hideFromAll': True,
#   'into': [],
#   'image': {'full': '1413.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 384,
#    'y': 144,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 525, 'purchasable': True, 'total': 2625, 'sell': 1837},
#   'tags': [],
#   'maps': {'1': False,
#    '8': False,
#    '10': True,
#    '11': True,
#    '12': False,
#    '14': False},
#   'stats': {'FlatHPPoolMod': 400.0},
#   'effect': {'Effect1Amount': '30',
#    'Effect2Amount': '25',
#    'Effect3Amount': '1.8',
#    'Effect4Amount': '5',
#    'Effect5Amount': '30',
#    'Effect6Amount': '3',
#    'Effect7Amount': '20',
#    'Effect8Amount': '18'},
#   'depth': 3},
#  '1414': {'name': '마법 부여: 룬의 메아리',
#   'description': '<stats>주문력 +60<br>이동 속도 +7% </stats><br><br><unique>고유 지속 효과 - 메아리:</unique> 이동하거나 스킬을 사용하면 중첩이 쌓입니다. 중첩이 100회 쌓이면 다음에 스킬로 피해를 입혔을 때 중첩을 모두 소모하여 최대 4명의 대상에게 60 (+ 주문력의 10%)의 추가 마법 피해를 입힙니다.<br><br> 대형 몬스터에게는 250%의 피해를 입히며, 이 효과가 대형 몬스터에게 적중하면 잃은 마나의 18%를 회복합니다.',
#   'colloq': ';',
#   'plaintext': '주문력이 증가하고 주기적으로 스킬이 강화됩니다.',
#   'from': ['3113', '1052', '3715'],
#   'hideFromAll': True,
#   'into': [],
#   'image': {'full': '1414.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 432,
#    'y': 144,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 340, 'purchasable': True, 'total': 2625, 'sell': 1837},
#   'tags': [],
#   'maps': {'1': False,
#    '8': False,
#    '10': True,
#    '11': True,
#    '12': False,
#    '14': False},
#   'stats': {'FlatMagicDamageMod': 60.0, 'PercentMovementSpeedMod': 0.07},
#   'effect': {'Effect1Amount': '30',
#    'Effect2Amount': '25',
#    'Effect3Amount': '1.8',
#    'Effect4Amount': '5',
#    'Effect5Amount': '30',
#    'Effect6Amount': '3',
#    'Effect7Amount': '20',
#    'Effect8Amount': '18'},
#   'depth': 3},
#  '1416': {'name': '마법 부여: 피갈퀴손',
#   'description': '<stats>공격 속도 +50%</stats><br><br><unique>고유 지속 효과:</unique> 기본 공격 적중 시 대상 최대 체력의 4%만큼 추가 물리 피해를 입힙니다. (몬스터와 미니언 상대로 최대 75)',
#   'colloq': ';',
#   'plaintext': '공격 속도가 증가하고 대상의 체력에 비례한 피해를 입힙니다.',
#   'from': ['1043', '3706'],
#   'hideFromAll': True,
#   'into': [],
#   'image': {'full': '1416.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 0,
#    'y': 192,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 625, 'purchasable': True, 'total': 2625, 'sell': 1837},
#   'tags': [],
#   'maps': {'1': False,
#    '8': False,
#    '10': True,
#    '11': True,
#    '12': False,
#    '14': False},
#   'stats': {'PercentAttackSpeedMod': 0.5},
#   'effect': {'Effect1Amount': '30',
#    'Effect2Amount': '25',
#    'Effect3Amount': '1.8',
#    'Effect4Amount': '5',
#    'Effect5Amount': '30',
#    'Effect6Amount': '-0.2',
#    'Effect7Amount': '2',
#    'Effect8Amount': '3'},
#   'depth': 3},
#  '1418': {'name': '마법 부여: 피갈퀴손',
#   'description': '<stats>공격 속도 +50%</stats><br><br><unique>고유 지속 효과:</unique> 기본 공격 적중 시 대상 최대 체력의 4%만큼 추가 물리 피해를 입힙니다. (몬스터와 미니언 상대로 최대 75)',
#   'colloq': ';',
#   'plaintext': '공격 속도가 증가하고 대상의 체력에 비례한 피해를 입힙니다.',
#   'from': ['1043', '3711'],
#   'hideFromAll': True,
#   'into': [],
#   'image': {'full': '1418.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 96,
#    'y': 192,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 625, 'purchasable': True, 'total': 2625, 'sell': 1837},
#   'tags': [],
#   'maps': {'1': False,
#    '8': False,
#    '10': False,
#    '11': True,
#    '12': False,
#    '14': False},
#   'stats': {'PercentAttackSpeedMod': 0.5},
#   'effect': {'Effect1Amount': '30',
#    'Effect2Amount': '25',
#    'Effect3Amount': '1.8',
#    'Effect4Amount': '5',
#    'Effect5Amount': '30',
#    'Effect6Amount': '3',
#    'Effect7Amount': '20',
#    'Effect8Amount': '30'},
#   'depth': 3},
#  '1419': {'name': '마법 부여: 피갈퀴손',
#   'description': '<stats>공격 속도 +50%</stats><br><br><unique>고유 지속 효과:</unique> 기본 공격 적중 시 대상 최대 체력의 4%만큼 추가 물리 피해를 입힙니다. (몬스터와 미니언 상대로 최대 75)',
#   'colloq': ';',
#   'plaintext': '공격 속도가 증가하고 대상의 체력에 비례한 피해를 입힙니다.',
#   'from': ['1043', '3715'],
#   'hideFromAll': True,
#   'into': [],
#   'image': {'full': '1419.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 144,
#    'y': 192,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 625, 'purchasable': True, 'total': 2625, 'sell': 1837},
#   'tags': [],
#   'maps': {'1': False,
#    '8': False,
#    '10': True,
#    '11': True,
#    '12': False,
#    '14': False},
#   'stats': {'PercentAttackSpeedMod': 0.5},
#   'effect': {'Effect1Amount': '30',
#    'Effect2Amount': '25',
#    'Effect3Amount': '1.8',
#    'Effect4Amount': '5',
#    'Effect5Amount': '30',
#    'Effect6Amount': '3',
#    'Effect7Amount': '20',
#    'Effect8Amount': '18'},
#   'depth': 3},
#  '2003': {'name': '체력 물약',
#   'description': '<groupLimit>한 번에 한 종류의 회복 물약만 최대 5개까지 소지할 수 있습니다.</groupLimit><br><br><consumable>클릭하여 사용:</consumable> 15초에 걸쳐 150의 체력을 회복합니다.',
#   'colloq': ';포션;체포;빨간;빨포;potion;health',
#   'plaintext': '사용하면 일정 시간 동안 체력이 회복됩니다.',
#   'consumed': True,
#   'stacks': 5.0,
#   'into': [],
#   'image': {'full': '2003.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 192,
#    'y': 192,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 50, 'purchasable': True, 'total': 50, 'sell': 20},
#   'tags': ['Consumable', 'Jungle', 'Lane'],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {},
#   'effect': {'Effect1Amount': '150', 'Effect2Amount': '15'}},
#  '2009': {'name': '원기회복의 완전한 비스킷',
#   'description': '<consumable>클릭하여 사용:</consumable> 10초에 걸쳐 체력 80과 마나 50을 회복합니다.',
#   'colloq': ';biscuit;rejuvenation',
#   'plaintext': '',
#   'consumed': True,
#   'inStore': False,
#   'into': [],
#   'image': {'full': '2009.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 240,
#    'y': 192,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 0, 'purchasable': False, 'total': 0, 'sell': 0},
#   'tags': [],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {}},
#  '2010': {'name': '원기회복의 완전한 비스킷',
#   'description': '<consumable>클릭하여 사용:</consumable> 즉시 15의 체력과 15의 마나를 회복한 다음, 15초에 걸쳐 150의 체력이 회복됩니다.',
#   'colloq': ';biscuit;rejuvenation',
#   'plaintext': '',
#   'consumed': True,
#   'stacks': 5.0,
#   'inStore': False,
#   'into': [],
#   'image': {'full': '2010.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 288,
#    'y': 192,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 50, 'purchasable': False, 'total': 50, 'sell': 20},
#   'tags': [],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {},
#   'effect': {'Effect1Amount': '15',
#    'Effect2Amount': '15',
#    'Effect3Amount': '150',
#    'Effect4Amount': '15'}},
#  '2015': {'name': '키르히아이스의 파편',
#   'description': "<stats>공격 속도 +15%</stats><br><br><passive>지속 효과:</passive> 이동 및 공격 시 <a href='Energized'>충전 상태</a>로 한 번 공격할 수 있게 됩니다.<br><br><unique>고유 지속 효과 - 충전된 일격:</unique> 충전 상태로 공격하여 적중 시 40의 추가 마법 피해를 입힙니다.",
#   'colloq': ';',
#   'plaintext': '공격 속도가 늘어나고 충전식 마법 피해를 입힙니다.',
#   'from': ['1042'],
#   'into': ['3087', '3094'],
#   'image': {'full': '2015.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 336,
#    'y': 192,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 450, 'purchasable': True, 'total': 750, 'sell': 525},
#   'tags': ['AttackSpeed', 'OnHit'],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {'PercentAttackSpeedMod': 0.15},
#   'effect': {'Effect1Amount': '40'},
#   'depth': 2},
#  '2031': {'name': '충전형 물약',
#   'description': '<groupLimit>한 번에 한 종류의 회복 물약만 소지할 수 있습니다.</groupLimit><br><br><active>고유 사용 효과:</active> 충전량을 1회 소모해 12초 동안 125의 체력을 회복합니다. 상점 방문 시 2회의 충전량이 다시 채워집니다.',
#   'colloq': ';',
#   'plaintext': '일정 시간 동안 체력이 회복되며, 상점에 가면 다시 충전됩니다.',
#   'into': ['2032', '2033'],
#   'image': {'full': '2031.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 384,
#    'y': 192,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 150, 'purchasable': True, 'total': 150, 'sell': 60},
#   'tags': ['Active', 'Consumable', 'HealthRegen', 'Jungle', 'Lane'],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {},
#   'effect': {'Effect1Amount': '125',
#    'Effect2Amount': '0',
#    'Effect3Amount': '12',
#    'Effect4Amount': '2'}},
#  '2032': {'name': '사냥꾼의 물약',
#   'description': '<groupLimit>한 번에 한 종류의 회복 물약만 소지할 수 있습니다.</groupLimit><br><br><active>고유 사용 효과:</active> 충전량을 1회 소모해 8초에 걸쳐 60의 체력과 35의 마나를 회복합니다. 상점 방문 시 5회의 충전량이 다시 채워집니다.<br><br>대형 몬스터 처치 시마다 1회의 충전량이 채워집니다.<br><br><rules>(충전량이 최대치에 도달한 상태로 대형 몬스터를 처치할 경우 새로 채워질 충전량은 자동으로 사용됩니다.)</rules>',
#   'colloq': ';',
#   'plaintext': '체력과 마나가 일정 시간 동안 회복됩니다. 상점에 가면 다시 충전되며 효율이 증가합니다.',
#   'from': ['2031'],
#   'into': [],
#   'image': {'full': '2032.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 432,
#    'y': 192,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 250, 'purchasable': True, 'total': 400, 'sell': 160},
#   'tags': ['Active', 'Consumable', 'HealthRegen', 'Jungle', 'ManaRegen'],
#   'maps': {'1': False,
#    '8': False,
#    '10': True,
#    '11': True,
#    '12': False,
#    '14': False},
#   'stats': {},
#   'effect': {'Effect1Amount': '60',
#    'Effect2Amount': '35',
#    'Effect3Amount': '8',
#    'Effect4Amount': '5'},
#   'depth': 2},
#  '2033': {'name': '부패 물약',
#   'description': "<groupLimit>한 번에 한 종류의 회복 물약만 소지할 수 있습니다.</groupLimit><br><br><active>고유 사용 효과:</active> 충전량을 1회 소모해 12초 동안 125의 체력과 75의 마나를 회복하고, 그 동안 <font color='#FF8811'><u>부패의 손길</u></font>을 활성화합니다. 상점 방문 시 3회의 충전량이 다시 채워집니다.<br><br><font color='#FF8811'><u>부패의 손길:</u></font> 적 챔피언에게 주문 및 공격으로 피해를 입히면 적을 불태워 3초 동안 <levelScale>15 - 30</levelScale>의 마법 피해를 입힙니다. (광역 및 지속 피해 스킬 사용 시에는 절반의 피해만 적용됩니다. 피해량은 챔피언 레벨에 비례해 증가합니다.)<br><br><rules>(부패 물약은 체력과 마나가 모두 차 있을 때도 사용할 수 있습니다.)</rules>",
#   'colloq': ';',
#   'plaintext': '체력과 마나가 일정 시간 동안 회복되고 전투 능력을 상승시킵니다. 상점에 가면 다시 충전됩니다.',
#   'from': ['2031'],
#   'into': [],
#   'image': {'full': '2033.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 0,
#    'y': 240,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 350, 'purchasable': True, 'total': 500, 'sell': 200},
#   'tags': ['Active', 'Consumable', 'HealthRegen', 'Lane', 'ManaRegen'],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {},
#   'effect': {'Effect1Amount': '125',
#    'Effect2Amount': '75',
#    'Effect3Amount': '12',
#    'Effect4Amount': '3',
#    'Effect5Amount': '10',
#    'Effect6Amount': '0.1',
#    'Effect7Amount': '15',
#    'Effect8Amount': '3'},
#   'depth': 2},
#  '2045': {'name': '루비 시야석',
#   'description': "<stats>체력 +500</stats><br><br><unique>고유 지속 효과:</unique> 사용 효과가 있는 아이템의 재사용 대기시간이 20% 줄어듭니다.<br><active>고유 사용 효과 - 와드 설치:</active> 충전량을 1회 소모하여 주변 지역을 150초 동안 드러내주는 <font color='#BBFFFF'>투명 와드</font>를 설치합니다. 상점 방문 시 4회의 충전량이 다시 채워집니다.<br><br><rules>(플레이어 당 <font color='#BBFFFF'>투명 와드</font>는 한 번에 3개까지만 맵에 설치할 수 있으며, 동일한 이름의 고유 지속 효과와 중첩되지 않습니다.)</rules>",
#   'colloq': ';ruby;sight;stone',
#   'plaintext': '체력이 대폭 늘어나고 계속해서 투명 와드를 얻을 수 있습니다.',
#   'from': ['2049', '1028'],
#   'into': [],
#   'image': {'full': '2045.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 96,
#    'y': 240,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 400, 'purchasable': True, 'total': 1600, 'sell': 640},
#   'tags': ['Active', 'Health', 'Vision'],
#   'maps': {'1': False,
#    '8': False,
#    '10': False,
#    '11': True,
#    '12': False,
#    '14': False},
#   'stats': {'FlatHPPoolMod': 500.0},
#   'effect': {'Effect1Amount': '-0.2',
#    'Effect2Amount': '4',
#    'Effect3Amount': '150'},
#   'depth': 3},
#  '2047': {'name': '예언자의 추출액',
#   'description': '<consumable>클릭하여 사용:</consumable> 5분 동안 주위의 투명하거나 보이지 않는 유닛을 감지하는 능력이 생깁니다.',
#   'colloq': ';오라클;oracle;extract',
#   'plaintext': '챔피언이 투명하거나 보이지 않는 적 유닛을 볼 수 있게 됩니다.',
#   'consumed': True,
#   'consumeOnFull': True,
#   'into': [],
#   'image': {'full': '2047.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 144,
#    'y': 240,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 300, 'purchasable': True, 'total': 300, 'sell': 120},
#   'tags': ['Consumable', 'Stealth', 'Vision'],
#   'maps': {'1': False,
#    '8': True,
#    '10': False,
#    '11': False,
#    '12': True,
#    '14': False},
#   'stats': {}},
#  '2049': {'name': '시야석',
#   'description': "<stats>체력 +150</stats><br><br><active>고유 사용 효과 - 와드 설치:</active> 충전량을 1회 소모하여 주변 지역을 150초 동안 드러내주는 <font color='#BBFFFF'>투명 와드</font>를 설치합니다. 상점 방문 시 3회의 충전량이 다시 채워집니다.<br><br><rules>(플레이어 당 <font color='#BBFFFF'>투명 와드</font>는 한 번에 3개까지만 맵에 설치할 수 있으며, 동일한 이름의 고유 지속 효과와 중첩되지 않습니다.)</rules>",
#   'colloq': ';sightstone;stone',
#   'plaintext': '체력이 늘어나고 계속해서 투명 와드를 얻을 수 있습니다.',
#   'from': ['1028'],
#   'into': ['2045', '2301', '2302', '2303'],
#   'image': {'full': '2049.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 192,
#    'y': 240,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 400, 'purchasable': True, 'total': 800, 'sell': 320},
#   'tags': ['Active', 'Health', 'Vision'],
#   'maps': {'1': False,
#    '8': False,
#    '10': False,
#    '11': True,
#    '12': False,
#    '14': False},
#   'stats': {'FlatHPPoolMod': 150.0},
#   'effect': {'Effect1Amount': '3', 'Effect2Amount': '150'},
#   'depth': 2},
#  '2050': {'name': '탐험가의 와드',
#   'description': '<consumable>클릭하여 사용:</consumable> 주변 지역을 60초 동안 드러내주는 투명한 와드를 설치합니다.',
#   'colloq': ';explorer;ward;mini',
#   'plaintext': '',
#   'inStore': False,
#   'into': [],
#   'image': {'full': '2050.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 240,
#    'y': 240,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 0, 'purchasable': False, 'total': 0, 'sell': 0},
#   'tags': ['Consumable'],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {}},
#  '2051': {'name': '수호자의 뿔피리',
#   'description': '<stats>체력 +150</stats><br><br><passive>기본 지속 효과:</passive> 5초마다 20의 체력을 회복합니다.<br><unique>고유 지속 효과:</unique> 적 챔피언의 기본 공격과 스킬 공격 피해량을 12만큼 막아줍니다. (지속 피해 스킬의 경우 25%의 효과).<br><br><groupLimit>수호자 아이템은 1개만 소유할 수 있습니다.</groupLimit>',
#   'colloq': 'Golden Arm of Kobe;Golden Bicep of Kobe;Horn; Horn of the ManWolf; ManWolf',
#   'plaintext': '탱커에게 특화된 시작 아이템입니다.',
#   'into': [],
#   'image': {'full': '2051.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 288,
#    'y': 240,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 950, 'purchasable': True, 'total': 950, 'sell': 380},
#   'tags': ['Health', 'HealthRegen', 'Lane'],
#   'maps': {'1': False,
#    '8': False,
#    '10': False,
#    '11': False,
#    '12': True,
#    '14': False},
#   'stats': {'FlatHPPoolMod': 150.0, 'FlatHPRegenMod': 4.0},
#   'effect': {'Effect1Amount': '12', 'Effect2Amount': '0.25'}},
#  '2052': {'name': '포로 간식',
#   'description': '방목해서 신선한 풀을 먹여 키운 아바로사 암탉과 화학 비료를 쓰지 않고 재배한 프렐요드산 유기농 허브로 맛있게 조리한 영양 만점 요리. 포로에게 먹이면 신나서 갸르릉거립니다.<br><br><i>수익금은 전액 녹서스 동물 학대 반대 운동 기금으로 기부됩니다.</i>',
#   'colloq': ';poro;snack;snax',
#   'plaintext': '',
#   'consumed': True,
#   'stacks': 2.0,
#   'inStore': False,
#   'into': [],
#   'image': {'full': '2052.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 336,
#    'y': 240,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 0, 'purchasable': False, 'total': 0, 'sell': 0},
#   'tags': [],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {}},
#  '2053': {'name': '칼날부리의 망토',
#   'description': '<stats>방어력 +40<br>기본 체력 재생 +125% </stats><br><br><unique>고유 지속 효과 - 단거리 주자:</unique> 포탑이나 무너진 포탑, 공허의 문 근처에서는 2초에 걸쳐 이동 속도가 최대 +20%까지 상승합니다.',
#   'colloq': ';',
#   'plaintext': '포탑 근처에서 이동 속도가 상승합니다.',
#   'from': ['1006', '1031'],
#   'into': ['3056', '3069', '3512'],
#   'image': {'full': '2053.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 384,
#    'y': 240,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 250, 'purchasable': True, 'total': 1200, 'sell': 840},
#   'tags': ['Armor', 'HealthRegen', 'NonbootsMovement'],
#   'maps': {'1': False,
#    '8': False,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {'FlatArmorMod': 40.0},
#   'effect': {'Effect1Amount': '20', 'Effect2Amount': '2'},
#   'depth': 3},
#  '2054': {'name': '다이어트 포로 간식',
#   'description': '맛은 그대로, 칼로리는 절반! 몸매에도 건강에도 좋은 신제품입니다.<br><br><consumable>클릭해서 사용:</consumable> 포로에게 맛있고 건강한 새 간식을 먹이세요.',
#   'colloq': ';',
#   'plaintext': '',
#   'consumed': True,
#   'inStore': False,
#   'into': [],
#   'image': {'full': '2054.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 432,
#    'y': 240,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 0, 'purchasable': False, 'total': 0, 'sell': 0},
#   'tags': [],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {}},
#  '2055': {'name': '제어 와드',
#   'description': "<groupLimit>제어 와드는 가방에 3개만 소지할 수 있습니다.</groupLimit><br><br><consumable>클릭하여 사용:</consumable> 주변 지역을 드러내 주는 와드를 설치합니다. 근처의 와드와 숨겨진 덫을 드러내고 무력화시킵니다. 위장 중인 유닛의 모습도 드러냅니다. 하지만 제어 와드로 다른 제어 와드를 무력화시킬 수는 없습니다.<br><br>플레이어 당 맵에 설치할 수 있는 <font color='#BBFFFF'>제어 와드</font>의 개수는  1개로 제한됩니다.",
#   'colloq': 'orange;',
#   'plaintext': '일정 지역 안의 와드와 투명 덫을 무력화시킵니다.',
#   'consumed': True,
#   'stacks': 3.0,
#   'into': [],
#   'image': {'full': '2055.png',
#    'sprite': 'item2.png',
#    'group': 'item',
#    'x': 144,
#    'y': 192,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 75, 'purchasable': True, 'total': 75, 'sell': 30},
#   'tags': ['Consumable', 'Lane', 'Stealth', 'Vision'],
#   'maps': {'1': False,
#    '8': False,
#    '10': False,
#    '11': True,
#    '12': False,
#    '14': False},
#   'stats': {},
#   'effect': {'Effect1Amount': '1', 'Effect2Amount': '3'}},
#  '2138': {'name': '강철의 영약',
#   'description': "<stats><levelLimit>9레벨 이상 구매 가능</levelLimit></stats><br><br><consumable>클릭하여 사용:</consumable> 3분 동안 체력이 +300, 강인함이 25% 증가하고, 챔피언이 거대해지며, <font color='#FF8811'><u>강철의 길</u></font> 효과가 생깁니다.<br><br><font color='#FF8811'><u>강철의 길:</u></font> 이동하면 뒤로 길이 생겨 그 위의 아군 챔피언들은 이동 속도가 15% 상승합니다.<br><br><rules>(영약 효과는 한 번에 하나만 활성화됩니다.)</rules>",
#   'colloq': ';white',
#   'plaintext': '일시적으로 방어 관련 능력치를 높여줍니다. 아군이 뒤따라올 수 있는 자취를 남깁니다.',
#   'consumed': True,
#   'consumeOnFull': True,
#   'into': [],
#   'image': {'full': '2138.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 0,
#    'y': 288,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 500, 'purchasable': True, 'total': 500, 'sell': 200},
#   'tags': ['Consumable', 'Health', 'NonbootsMovement', 'Tenacity'],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {},
#   'effect': {'Effect1Amount': '300',
#    'Effect2Amount': '0.25',
#    'Effect3Amount': '3',
#    'Effect4Amount': '0.15',
#    'Effect5Amount': '0.15',
#    'Effect6Amount': '0',
#    'Effect7Amount': '0',
#    'Effect8Amount': '9'}},
#  '2139': {'name': '마법의 영약',
#   'description': "<stats><levelLimit>9레벨 이상 구매 가능</levelLimit></stats><br><br><consumable>클릭하여 사용:</consumable> 3분 동안 주문력 +50, 5초당 마나 재생량이 +15 오르며 <font color='#FF8811'><u>마법</u></font> 효과가 생깁니다. <br><br><font color='#FF8811'><u>마법:</u></font> 챔피언이나 포탑에 피해를 입히면 25의 추가 고정 피해를 입힙니다. 이 효과는 챔피언 상대로는 5초의 재사용 대기시간이 적용되지만, 포탑을 공격할 때는 재사용 대기시간이 없습니다.<br><br><rules>(영약 효과는 한 번에 하나만 활성화됩니다.)</rules><br>",
#   'colloq': ';blue',
#   'plaintext': '일시적으로 주문력을 올려주며, 챔피언과 포탑에 대한 추가 피해량이 적용됩니다.',
#   'consumed': True,
#   'consumeOnFull': True,
#   'into': [],
#   'image': {'full': '2139.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 48,
#    'y': 288,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 500, 'purchasable': True, 'total': 500, 'sell': 200},
#   'tags': ['Consumable', 'ManaRegen', 'SpellDamage'],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {},
#   'effect': {'Effect1Amount': '50',
#    'Effect2Amount': '50',
#    'Effect3Amount': '25',
#    'Effect4Amount': '3',
#    'Effect5Amount': '5',
#    'Effect6Amount': '3',
#    'Effect7Amount': '0',
#    'Effect8Amount': '9'}},
#  '2140': {'name': '분노의 영약',
#   'description': "<stats><levelLimit>9레벨 이상 구매 가능</levelLimit></stats><br><br><consumable>클릭하여 사용:</consumable> 3분 동안 공격력이 +30 상승하고 <font color='#FF8811'><u>피의 갈망</u></font> 효과가 생깁니다.<br><br><font color='#FF8811'><u>피의 갈망:</u></font> 챔피언에게 물리 피해를 입히면, 입힌 피해량의 15%만큼 체력이 회복됩니다.<br><br><rules>(영약 효과는 한 번에 하나만 활성화됩니다.)</rules>",
#   'colloq': ';red',
#   'plaintext': '일시적으로 공격력을 올려주며, 챔피언에게 물리 피해를 입히면 체력이 회복됩니다.',
#   'consumed': True,
#   'consumeOnFull': True,
#   'into': [],
#   'image': {'full': '2140.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 96,
#    'y': 288,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 500, 'purchasable': True, 'total': 500, 'sell': 200},
#   'tags': ['Consumable', 'Damage', 'LifeSteal', 'SpellVamp'],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {},
#   'effect': {'Effect1Amount': '30',
#    'Effect2Amount': '30',
#    'Effect3Amount': '0.15',
#    'Effect4Amount': '3',
#    'Effect5Amount': '0',
#    'Effect6Amount': '0',
#    'Effect7Amount': '0',
#    'Effect8Amount': '9'}},
#  '2301': {'name': '수호자의 눈',
#   'description': "<stats>체력 +200<br><mana>기본 마나 재생 +100% </mana><br>주문력 +25<br>재사용 대기시간 감소 +10%<br>10초당 골드 +2</stats><br><br><unique>고유 지속 효과 - 헌납:</unique> 챔피언과 구조물에 대한 스킬과 기본 공격 시 15의 추가 피해를 입히고 15골드를 획득합니다. 30초당 최대 3번까지만 발동합니다.<br><active>고유 사용 효과 - 와드 설치:</active> 충전량을 1회 소모하여 주변 지역을 150초 동안 드러내주는 <font color='#BBFFFF'>투명 와드</font>를 설치합니다. 상점 방문 시 4회의 충전량이 다시 채워집니다.<br><br><groupLimit>골드 획득 아이템은 1개로 소지가 제한됩니다.</groupLimit><br><br><rules>(플레이어 당 <font color='#BBFFFF'>투명 와드</font>는 한 번에 3개까지만 맵에 설치할 수 있으며, 동일한 이름의 고유 지속 효과와 중첩되지 않습니다.)</rules>",
#   'colloq': ';',
#   'plaintext': '주문력이 증가하며 투명 와드를 지속적으로 공급합니다.',
#   'from': ['2049', '3098'],
#   'into': [],
#   'image': {'full': '2301.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 144,
#    'y': 288,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 550, 'purchasable': True, 'total': 2200, 'sell': 880},
#   'tags': ['Active',
#    'CooldownReduction',
#    'GoldPer',
#    'Health',
#    'ManaRegen',
#    'SpellDamage',
#    'Vision'],
#   'maps': {'1': False,
#    '8': False,
#    '10': False,
#    '11': True,
#    '12': False,
#    '14': False},
#   'stats': {'FlatHPPoolMod': 200.0, 'FlatMagicDamageMod': 25.0},
#   'effect': {'Effect1Amount': '2',
#    'Effect2Amount': '15',
#    'Effect3Amount': '15',
#    'Effect4Amount': '4',
#    'Effect5Amount': '30',
#    'Effect6Amount': '12',
#    'Effect7Amount': '150',
#    'Effect8Amount': '3'},
#   'depth': 3},
#  '2302': {'name': '오아시스의 눈',
#   'description': "<stats>체력 +200<br>기본 체력 재생 +100% <br><mana>기본 마나 재생 +100% </mana><br>재사용 대기시간 감소 +10%</stats><br><br><unique>고유 지속 효과 - 나눠받기:</unique> 주변에서 내가 최후의 일격을 가하지 않은 미니언이 쓰러지면 6골드와 체력 10을 얻습니다.<br><active>고유 사용 효과 - 와드 설치:</active> 충전량을 1회 소모하여 주변 지역을 150초 동안 드러내주는 <font color='#BBFFFF'>투명 와드</font>를 설치합니다. 상점 방문 시 4회의 충전량이 다시 채워집니다.<br><br><groupLimit>골드 획득 아이템은 1개로 소지가 제한됩니다.</groupLimit><br><br><rules>(플레이어 당 <font color='#BBFFFF'>투명 와드</font>는 한 번에 3개까지만 맵에 설치할 수 있으며, 동일한 이름의 고유 지속 효과와 중첩되지 않습니다.)</rules>",
#   'colloq': ';',
#   'plaintext': '체력 재생이 증가하며 투명 와드를 지속적으로 공급합니다.',
#   'from': ['2049', '3096'],
#   'into': [],
#   'image': {'full': '2302.png',
#    'sprite': 'item0.png',
#    'group': 'item',
#    'x': 192,
#    'y': 288,
# ...
#   'effect': {'Effect1Amount': '4',
#    'Effect2Amount': '120',
#    'Effect3Amount': '700',
#    'Effect4Amount': '2.35',
#    'Effect5Amount': '560',
#    'Effect6Amount': '705',
#    'Effect7Amount': '1479'}},
#  '3682': {'name': '에스프레소 간식',
#   'description': "<active>사용 시 - <a href='FeedTheKing'>왕에게 먹이를</a>:</active> 왕이 공중으로 뛰어올랐다가 두 차례 땅으로 떨어질 때마다 적을 밀어내고 <levelScale>40~190</levelScale>의 물리 피해를 입힙니다. 포로 왕에게는 <font color='#FF3300'>최대 체력의 20%</font>에 해당하는 보호막이 생기며, 보호막은 4초에 걸쳐 사라집니다. (재사용 대기시간 30초)",
#   'colloq': ';',
#   'plaintext': '왕이 적을 뒤로 밀어내고 거대한 보호막을 얻습니다.',
#   'into': [],
#   'image': {'full': '3682.png',
#    'sprite': 'item2.png',
#    'group': 'item',
#    'x': 0,
#    'y': 240,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 0, 'purchasable': True, 'total': 0, 'sell': 0},
#   'tags': ['Lane', 'Trinket'],
#   'maps': {'1': False,
#    '8': False,
#    '10': False,
#    '11': False,
#    '12': True,
#    '14': False},
#   'stats': {},
#   'effect': {'Effect1Amount': '1.8',
#    'Effect2Amount': '30',
#    'Effect3Amount': '10',
#    'Effect4Amount': '10',
#    'Effect5Amount': '20',
#    'Effect6Amount': '4',
#    'Effect7Amount': '600',
#    'Effect8Amount': '40'}},
#  '3683': {'name': '무지개 간식 파티 세트',
#   'description': "<active>사용 시 - <a href='FeedTheKing'>왕에게 먹이를</a>:</active> 왕이 적 뒤로 간식을 잔뜩 던져 포로들을 유인한 뒤 다시 자신에게 돌아오게 합니다. 포로와 부딪힌 적 챔피언은 앞으로 밀려나며 <levelScale>230~680</levelScale>의 물리 피해를 입습니다. (재사용 대기시간 120초)",
#   'colloq': ';',
#   'plaintext': '왕이 던진 포로들이 적을 왕 쪽으로 밀어냅니다.',
#   'into': [],
#   'image': {'full': '3683.png',
#    'sprite': 'item2.png',
#    'group': 'item',
#    'x': 48,
#    'y': 240,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 0, 'purchasable': True, 'total': 0, 'sell': 0},
#   'tags': ['Lane', 'Trinket'],
#   'maps': {'1': False,
#    '8': False,
#    '10': False,
#    '11': False,
#    '12': True,
#    '14': False},
#   'stats': {},
#   'effect': {'Effect1Amount': '6',
#    'Effect2Amount': '120',
#    'Effect3Amount': '140',
#    'Effect4Amount': '30',
#    'Effect5Amount': '1',
#    'Effect6Amount': '1500',
#    'Effect7Amount': '1650',
#    'Effect8Amount': '1000'}},
#  '3706': {'name': '추적자의 검',
#   'description': "<groupLimit>정글 아이템은 1개로 소지가 제한됩니다.</groupLimit><br><br><stats>몬스터 대상 생명력 흡수 +10%<br><mana>정글에서 기본 마나 재생 +180%</mana></stats><br><br><unique>기본 지속 효과 - 혹한의 강타:</unique> 강타를 적 챔피언에게 사용할 수 있습니다. 대상에게 사용 시 줄어든 고정 피해를 입히며, 대상의 이동 속도를 2초간 20% 훔칩니다.<br><unique>고유 지속 효과 - 이빨과 손톱:</unique> 몬스터에게 기본 공격 시 25의 추가 피해를 입힙니다. 스킬 혹은 공격으로 몬스터에게 피해를 입히면 5초 동안 30의 체력을 훔칩니다. 몬스터 처치 시에는 <font color='#99BBBB'><a href='SpecialJungleExperience'>특별 추가 경험치</a></font>를 얻습니다.",
#   'colloq': ';jungle;Jungle;정글',
#   'plaintext': '강타를 챔피언에게 사용하여 둔화시킵니다.',
#   'from': ['1039', '1041'],
#   'into': ['1400', '1401', '1402', '1416'],
#   'image': {'full': '3706.png',
#    'sprite': 'item2.png',
#    'group': 'item',
#    'x': 0,
#    'y': 48,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 300, 'purchasable': True, 'total': 1000, 'sell': 700},
#   'tags': ['Jungle',
#    'LifeSteal',
#    'ManaRegen',
#    'NonbootsMovement',
#    'OnHit',
#    'Slow'],
#   'maps': {'1': False,
#    '8': False,
#    '10': True,
#    '11': True,
#    '12': False,
#    '14': False},
#   'stats': {},
#   'effect': {'Effect1Amount': '30',
#    'Effect2Amount': '25',
#    'Effect3Amount': '1.8',
#    'Effect4Amount': '5',
#    'Effect5Amount': '30',
#    'Effect6Amount': '-0.2',
#    'Effect7Amount': '2',
#    'Effect8Amount': '3'},
#   'depth': 2},
#  '3711': {'name': '추격자의 나이프',
#   'description': "<groupLimit>정글 아이템은 1개로 소지가 제한됩니다.</groupLimit><br><br><stats>몬스터 상대 생명력 흡수 +10%<br><mana>정글에서 기본 마나 재생 +180%</mana></stats><br><br><unique>고유 지속 효과 - 이빨과 손톱:</unique> 몬스터에게 기본 공격 시 25의 추가 피해를 입힙니다. 스킬 혹은 공격으로 몬스터에게 피해를 입히면 5초 동안 30의 체력을 훔칩니다. 몬스터 처치 시에는 <font color='#99BBBB'><a href='SpecialJungleExperience'>특별 추가 경험치</a></font>를 얻습니다.<br><active>고유 사용 효과 - 와드 설치:</active> 충전량을 1회 소모하여 주변 지역을 150초간 드러내주는 <font color='#BBFFFF'>투명 와드</font>를 설치합니다. 상점 방문 시 2회의 충전량이 다시 채워집니다.<br><br><rules>(플레이어 당 <font color='#BBFFFF'>투명 와드</font>는 한 번에 3개까지만 맵에 설치할 수 있습니다. 동일한 이름의 고유 지속 효과와 중첩되지 않습니다.)</rules>",
#   'colloq': ';jungle;Jungle;정글',
#   'plaintext': '계속해서 투명 와드를 얻을 수 있습니다.',
#   'from': ['1039', '1041'],
#   'into': ['1408', '1409', '1410', '1418'],
#   'image': {'full': '3711.png',
#    'sprite': 'item2.png',
#    'group': 'item',
#    'x': 48,
#    'y': 48,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 300, 'purchasable': True, 'total': 1000, 'sell': 700},
#   'tags': ['Active', 'Jungle', 'LifeSteal', 'ManaRegen', 'OnHit', 'Vision'],
#   'maps': {'1': False,
#    '8': False,
#    '10': False,
#    '11': True,
#    '12': False,
#    '14': False},
#   'stats': {},
#   'effect': {'Effect1Amount': '30',
#    'Effect2Amount': '25',
#    'Effect3Amount': '1.8',
#    'Effect4Amount': '5',
#    'Effect5Amount': '30',
#    'Effect6Amount': '3',
#    'Effect7Amount': '20',
#    'Effect8Amount': '30'},
#   'depth': 2},
#  '3715': {'name': '척후병의 사브르',
#   'description': "<groupLimit>정글 아이템은 1개로 소지가 제한됩니다.</groupLimit><br><br><stats>몬스터 상대 생명력 흡수 +10%<br><mana>정글에서 기본 마나 재생 +180%</mana></stats><br><br><passive>기본 지속 효과 - 승부의 강타:</passive> 강타를 적 챔피언에게 사용하여 4초 동안 표식을 남깁니다. 표식이 있는 대상은 위치가 드러나며, 시전자의 기본 공격에 맞으면 3초에 걸쳐 추가 고정 피해를 입고, 시전자에게 주는 피해량이 20% 감소합니다.<br><unique>고유 지속 효과 - 이빨과 손톱:</unique> 몬스터에게 기본 공격 시 25의 추가 피해를 입힙니다. 스킬 혹은 공격으로 몬스터에게 피해를 입히면 5초 동안 30의 체력을 훔칩니다. 몬스터 처치 시에는 <font color='#99BBBB'><a href='SpecialJungleExperience'>특별 추가 경험치</a></font>를 얻습니다.",
#   'colloq': ';jungle;Jungle;정글',
#   'plaintext': '강타로 챔피언에게 표식을 남겨, 이 챔피언에 대한 전투력을 올려줍니다.',
#   'from': ['1039', '1041'],
#   'into': ['1412', '1413', '1414', '1419'],
#   'image': {'full': '3715.png',
#    'sprite': 'item2.png',
#    'group': 'item',
#    'x': 96,
#    'y': 48,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 300, 'purchasable': True, 'total': 1000, 'sell': 700},
#   'tags': ['Jungle', 'LifeSteal', 'ManaRegen', 'OnHit'],
#   'maps': {'1': False,
#    '8': False,
#    '10': True,
#    '11': True,
#    '12': False,
#    '14': False},
#   'stats': {},
#   'effect': {'Effect1Amount': '30',
#    'Effect2Amount': '25',
#    'Effect3Amount': '1.8',
#    'Effect4Amount': '5',
#    'Effect5Amount': '30',
#    'Effect6Amount': '3',
#    'Effect7Amount': '20',
#    'Effect8Amount': '18'},
#   'depth': 2},
#  '3742': {'name': '망자의 갑옷',
#   'description': "<stats>체력 +500<br>방어력 +50</stats><br><br><unique>고유 지속 효과 - 전함:</unique> 이동 시 추진력 중첩이 쌓여, 100 중첩이 되면 이동 속도가 최대 60까지 상승합니다. 추진력은 기절, 도발, 공포, 변이, 이동 불가 효과의 영향을 받으면 빠르게 줄어들며, 둔화된 동안에는 서서히 효력이 줄어듭니다.<br><unique>고유 지속 효과 - 강력한 일격:</unique> 기본 공격 시 추진력이 방출되어 2 중첩 당 1의 물리 피해를 입힙니다. 100 중첩이 방출되면 피해량이 두 배가 되며 대상의 속도가 50% 느려져서 1초에 걸쳐 서서히 회복됩니다. (근접 전용)<br><br><flavorText>''내 갑옷을 뺏을 방도는 하나 뿐이다...'' - 무명씨</flavorText>",
#   'colloq': ';juggernaut;dreadnought',
#   'plaintext': '이동 시 추진력이 올라 적들을 강하게 타격합니다.',
#   'from': ['1031', '1011'],
#   'into': [],
#   'image': {'full': '3742.png',
#    'sprite': 'item2.png',
#    'group': 'item',
#    'x': 144,
#    'y': 48,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 1100, 'purchasable': True, 'total': 2900, 'sell': 2030},
#   'tags': ['Armor', 'Bilgewater', 'Health', 'NonbootsMovement', 'OnHit'],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {'FlatHPPoolMod': 500.0, 'FlatArmorMod': 50.0},
#   'effect': {'Effect1Amount': '60',
#    'Effect2Amount': '100',
#    'Effect3Amount': '2',
#    'Effect4Amount': '-0.5',
#    'Effect5Amount': '1'},
#   'depth': 3},
#  '3748': {'name': '거대한 히드라',
#   'description': '<stats>체력 +450<br>공격력 +35<br>기본 체력 재생 +100% </stats><br><br><unique>고유 지속 효과 - 베기:</unique> 기본 공격 적중 시 5 + 자신의 최대 체력의 1%에 해당하는 추가 물리 피해를 대상에게, 40 + 자신의 최대 체력의 2.5%에 해당하는 물리 피해를 원뿔 형태의 지역 안에 있는 다른 적들에게 입힙니다.<br><active>고유 사용 효과 - 초승달:</active> 다음 번 기본 공격은 더 큰 원뿔 형태 지역에 적용되며, 베기의 모든 대상에 대한 피해량이 늘어나 40 + 자신의 최대 체력의 10%에 해당하는 추가 물리 피해를 입힙니다. (재사용 대기시간 20초)<br><br><rules>(동일한 이름의 고유 지속 효과와 중첩되지 않습니다.)</rules>',
#   'colloq': ';juggernaut',
#   'plaintext': '본인 체력에 비례하여 광역 피해를 입힙니다.',
#   'from': ['3077', '1028', '3052'],
#   'into': [],
#   'image': {'full': '3748.png',
#    'sprite': 'item2.png',
#    'group': 'item',
#    'x': 192,
#    'y': 48,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 700, 'purchasable': True, 'total': 3500, 'sell': 2450},
#   'tags': ['Active', 'Damage', 'Health', 'HealthRegen', 'OnHit'],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {'FlatHPPoolMod': 450.0, 'FlatPhysicalDamageMod': 35.0},
#   'effect': {'Effect1Amount': '0.025',
#    'Effect2Amount': '40',
#    'Effect3Amount': '0',
#    'Effect4Amount': '0',
#    'Effect5Amount': '0.1',
#    'Effect6Amount': '0',
#    'Effect7Amount': '20',
#    'Effect8Amount': '40'},
#   'depth': 3},
#  '3751': {'name': '바미의 불씨',
#   'description': '<stats>체력 +280</stats><br><br><unique>고유 지속 효과 - 불사르기:</unique> 근처 적에게 초당 5 (챔피언 레벨당 +1)의 마법 피해를 입힙니다. 미니언과 몬스터에게는 50%의 추가 피해를 입힙니다.',
#   'colloq': ';jungle;Jungle;정글',
#   'plaintext': '체력과 불사르기 오오라를 제공합니다.',
#   'from': ['1028'],
#   'into': ['3068', '3717', '3725', '1401', '1409', '1413', '3672'],
#   'image': {'full': '3751.png',
#    'sprite': 'item2.png',
#    'group': 'item',
#    'x': 240,
#    'y': 48,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 700, 'purchasable': True, 'total': 1100, 'sell': 770},
#   'tags': ['Health'],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {'FlatHPPoolMod': 280.0},
#   'effect': {'Effect1Amount': '5',
#    'Effect2Amount': '1',
#    'Effect3Amount': '50'},
#   'depth': 2},
#  '3800': {'name': '정당한 영광',
#   'description': '<stats>체력 +500<br><mana>마나 +300</mana><br>기본 체력 재생 +100% </stats><br><br><unique>고유 지속 효과 - 영원:</unique> 챔피언으로부터 입은 피해의 15%를 마나로 돌려받습니다. 마나 소모 시 20%를 체력으로 돌려받습니다. (스킬 사용 1회당 최대 25까지)<br><unique>고유 사용 효과:</unique> 적이나 적 포탑 쪽으로 이동할 때는 4초간 이동 속도가 +75% 상승합니다. 3초가 지나면 충격파를 발산하여 2초간 주변 적 챔피언의 이동 속도를 75% 늦춥니다. (재사용 대기시간 90초)<br><br>효과가 활성화된 상태에서 다시 사용하면, 기다릴 필요 없이 충격파를 즉시 발산할 수 있습니다.',
#   'colloq': ';',
#   'plaintext': '체력과 마나가 증가합니다. 사용하면 적을 향해 갈 때 속도가 상승하며 적을 둔화시킵니다.',
#   'from': ['3010', '3801'],
#   'into': [],
#   'image': {'full': '3800.png',
#    'sprite': 'item2.png',
#    'group': 'item',
#    'x': 288,
#    'y': 48,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 750, 'purchasable': True, 'total': 2500, 'sell': 1750},
#   'tags': ['Active',
#    'Health',
#    'HealthRegen',
#    'Mana',
#    'ManaRegen',
#    'NonbootsMovement',
#    'Slow'],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {'FlatHPPoolMod': 500.0, 'FlatMPPoolMod': 300.0},
#   'effect': {'Effect1Amount': '0.75',
#    'Effect2Amount': '4',
#    'Effect3Amount': '-0.75',
#    'Effect4Amount': '2',
#    'Effect5Amount': '90',
#    'Effect6Amount': '0.2',
#    'Effect7Amount': '25',
#    'Effect8Amount': '0.15'},
#   'depth': 3},
#  '3801': {'name': '수정 팔 보호구',
#   'description': '<stats>체력 +200<br>기본 체력 재생 +50% </stats>',
#   'colloq': ';',
#   'plaintext': '체력과 체력 재생량이 상승합니다.',
#   'from': ['1028', '1006'],
#   'into': ['3083', '3084', '3107', '3109', '3800'],
#   'image': {'full': '3801.png',
#    'sprite': 'item2.png',
#    'group': 'item',
#    'x': 336,
#    'y': 48,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 100, 'purchasable': True, 'total': 650, 'sell': 455},
#   'tags': ['Health', 'HealthRegen'],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {'FlatHPPoolMod': 200.0},
#   'depth': 2},
#  '3802': {'name': '사라진 양피지',
#   'description': '<stats>주문력 +25<br><mana>마나 +300</mana></stats><br><br><unique>고유 지속 효과:</unique> 레벨이 오를 때마다 3초에 걸쳐 최대 마나의 20%를 회복합니다.',
#   'colloq': ';',
#   'plaintext': '레벨이 오를 때마다 마나를 회복합니다.',
#   'from': ['1052', '1027'],
#   'into': ['3165'],
#   'image': {'full': '3802.png',
#    'sprite': 'item2.png',
#    'group': 'item',
#    'x': 384,
#    'y': 48,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 115, 'purchasable': True, 'total': 900, 'sell': 630},
#   'tags': ['Mana', 'ManaRegen', 'SpellDamage'],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {'FlatMPPoolMod': 300.0, 'FlatMagicDamageMod': 25.0},
#   'effect': {'Effect1Amount': '25',
#    'Effect2Amount': '-0.1',
#    'Effect3Amount': '15',
#    'Effect4Amount': '10',
#    'Effect5Amount': '20',
#    'Effect6Amount': '5',
#    'Effect7Amount': '0.2',
#    'Effect8Amount': '3'},
#   'depth': 2},
#  '3812': {'name': '죽음의 무도',
#   'description': '<stats>공격력 +75<br>재사용 대기시간 감소 +10%</stats><br><br><unique>고유 지속 효과:</unique> 물리 피해를 가하면 가한 피해의 15%만큼 회복합니다. 이 효과는 범위 피해에는 33%만 적용됩니다.<br><unique>고유 지속 효과:</unique> 입은 피해의 15%가 3초 동안 지속되는 출혈 효과로 전환됩니다.',
#   'colloq': ';Bloodbag',
#   'plaintext': '입은 피해 적용이 잠시 미뤄집니다.',
#   'stacks': 0.0,
#   'from': ['1053', '1037', '3133'],
#   'into': [],
#   'image': {'full': '3812.png',
#    'sprite': 'item2.png',
#    'group': 'item',
#    'x': 432,
#    'y': 48,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 625, 'purchasable': True, 'total': 3500, 'sell': 2450},
#   'tags': ['CooldownReduction', 'Damage', 'LifeSteal'],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {'FlatPhysicalDamageMod': 75.0},
#   'effect': {'Effect1Amount': '0.15',
#    'Effect2Amount': '0.15',
#    'Effect3Amount': '3'},
#   'depth': 3},
#  '3814': {'name': '밤의 끝자락',
#   'description': "<stats>공격력 +60<br>마법 저항력 +35</stats><br><br><unique>고유 지속 효과:</unique><a href='Lethality'>물리 관통력</a> +15<br><unique>고유 지속 효과:</unique> 전투에서 벗어났을 때 이동 속도 +20<br><unique>고유 사용 효과 - 밤의 장막:</unique> 1.5초 동안 정신을 집중해 다음 적의 스킬 공격을 막아주는 보호막을 생성합니다. 보호막은 10초 동안 유지됩니다. (재사용 대기시간 45초)<br><br><rules>(정신 집중 중 이동은 할 수 있지만 피해를 입으면 정신 집중 상태가 종료됩니다.)</rules>",
#   'colloq': ';물리관통력',
#   'plaintext': '다음 적의 스킬 공격을 막습니다.',
#   'stacks': 0.0,
#   'from': ['1037', '3134', '1033'],
#   'into': [],
#   'image': {'full': '3814.png',
#    'sprite': 'item2.png',
#    'group': 'item',
#    'x': 336,
#    'y': 192,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 675, 'purchasable': True, 'total': 3100, 'sell': 2170},
#   'tags': ['ArmorPenetration', 'Damage', 'NonbootsMovement', 'SpellBlock'],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {'FlatPhysicalDamageMod': 60.0, 'FlatSpellBlockMod': 35.0},
#   'effect': {'Effect1Amount': '15',
#    'Effect2Amount': '0',
#    'Effect3Amount': '20',
#    'Effect4Amount': '45',
#    'Effect5Amount': '5'},
#   'depth': 3},
#  '3901': {'name': '가차없는 포격',
#   'description': '바다뱀 은화 500닢이 필요합니다.<br><br><unique>고유 지속 효과:</unique> 이제 포탄 세례가 시간이 갈수록 빠르게 발사됩니다. (지속 시간 동안 추가 6차례 발사)',
#   'colloq': '',
#   'plaintext': '포탄 세례의 포격 횟수가 늘어납니다.',
#   'consumed': True,
#   'consumeOnFull': True,
#   'requiredChampion': 'Gangplank',
#   'into': [],
#   'image': {'full': '3901.png',
#    'sprite': 'item2.png',
#    'group': 'item',
#    'x': 0,
#    'y': 96,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 0, 'purchasable': True, 'total': 0, 'sell': 0},
#   'tags': [],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {}},
#  '3902': {'name': '죽음의 여신',
#   'description': '바다뱀 은화 500닢이 필요합니다.<br><br><unique>고유 지속 효과:</unique> 포탄 세례가 범위 중앙에 추가로 대형 포탄을 하나 발사하여 300%의 고정 피해를 입히고 1.5초간 60% 둔화를 적용합니다. ',
#   'colloq': '',
#   'plaintext': '포탄 세례로 대형 포탄을 발사합니다.',
#   'consumed': True,
#   'consumeOnFull': True,
#   'requiredChampion': 'Gangplank',
#   'into': [],
#   'image': {'full': '3902.png',
#    'sprite': 'item2.png',
#    'group': 'item',
#    'x': 48,
#    'y': 96,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 0, 'purchasable': True, 'total': 0, 'sell': 0},
#   'tags': [],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {}},
#  '3903': {'name': '사기진작',
#   'description': '바다뱀 은화 500닢이 필요합니다.<br><br><unique>고유 지속 효과:</unique> 포탄 세례 범위 안의 아군은 이제 2초간 이동 속도가 30% 상승합니다.',
#   'colloq': '',
#   'plaintext': '포탄 세례로 아군의 속도를 상승시킵니다.',
#   'consumed': True,
#   'consumeOnFull': True,
#   'requiredChampion': 'Gangplank',
#   'into': [],
#   'image': {'full': '3903.png',
#    'sprite': 'item2.png',
#    'group': 'item',
#    'x': 96,
#    'y': 96,
#    'w': 48,
#    'h': 48},
#   'gold': {'base': 0, 'purchasable': True, 'total': 0, 'sell': 0},
#   'tags': [],
#   'maps': {'1': False,
#    '8': True,
#    '10': True,
#    '11': True,
#    '12': True,
#    '14': False},
#   'stats': {}}}

# %%
items = get_item_json()
# items.keys()
items['1001']
# Out:
# {'name': '속도의 장화',
#  'description': '<groupLimit>1개만 구입 가능합니다.</groupLimit><br><br><unique>고유 지속 효과 - 이동 속도 향상:</unique> 이동 속도 +25',
#  'colloq': ';똥신;boots;speed',
#  'plaintext': '이동 속도가 약간 증가합니다.',
#  'into': ['3006', '3047', '3020', '3158', '3111', '3117', '3009'],
#  'image': {'full': '1001.png',
#   'sprite': 'item0.png',
#   'group': 'item',
#   'x': 0,
#   'y': 0,
#   'w': 48,
#   'h': 48},
#  'gold': {'base': 300, 'purchasable': True, 'total': 300, 'sell': 210},
#  'tags': ['Boots'],
#  'maps': {'1': False,
#   '8': True,
#   '10': True,
#   '11': True,
#   '12': True,
#   '14': False},
#  'stats': {'FlatMovementSpeedMod': 25.0}}

# %%
for i in range(10):
    pprint(data['participantIdentities'][i])
# Out:
# {'participantId': 1,
#  'player': {'accountId': 'qNXNRXeaHw0yIzUOCZ3n9AykC7dC9ilUa-P1Ga2N8WJQYAwKsDQXugRa',
#             'currentAccountId': 'qNXNRXeaHw0yIzUOCZ3n9AykC7dC9ilUa-P1Ga2N8WJQYAwKsDQXugRa',
#             'currentPlatformId': 'KR',
#             'matchHistoryUri': '/v1/stats/player_history/KR/2150347147423040',
#             'platformId': 'KR',
#             'profileIcon': 4019,
#             'summonerId': 'woAW9tVNgLZDQJNaZixh9NBlxpUY-oVf0xC6p3pP1wz8BgA',
#             'summonerName': '사랑이아빠입니다'}}
# {'participantId': 2,
#  'player': {'accountId': 'jVxftZpF9ABjuSfjliH7GcTnvnvLwk4-X3N7W54YOoZmcSf7rBI3I-LR',
#             'currentAccountId': 'jVxftZpF9ABjuSfjliH7GcTnvnvLwk4-X3N7W54YOoZmcSf7rBI3I-LR',
#             'currentPlatformId': 'KR',
#             'matchHistoryUri': '/v1/stats/player_history/KR/1979971983519360',
#             'platformId': 'KR',
#             'profileIcon': 4022,
#             'summonerId': 'CM-ZNZl0hjnjZjnntX4MUF-UkMx_Kn3Ky23boOc8HXLZaDI',
#             'summonerName': '낄껴하자'}}
# {'participantId': 3,
#  'player': {'accountId': '_orAgNiEpi5ZFo_epsWr8BPqj5K6hGD9tPu5NIn0b24SM2M',
#             'currentAccountId': '_orAgNiEpi5ZFo_epsWr8BPqj5K6hGD9tPu5NIn0b24SM2M',
#             'currentPlatformId': 'KR',
#             'matchHistoryUri': '/v1/stats/player_history/kr/210564692',
#             'platformId': 'kr',
#             'profileIcon': 22,
#             'summonerId': '0SQiSRoAZ8gPG0cDo0C9KM0iywmApF3MkyUWSSV1h3ei_no',
#             'summonerName': '덮어쓰기'}}
# {'participantId': 4,
#  'player': {'accountId': 'HOBGu_R854vWCQC0IhlgQVo3MElwoyoA8wadN5ke5uvV',
#             'currentAccountId': 'HOBGu_R854vWCQC0IhlgQVo3MElwoyoA8wadN5ke5uvV',
#             'currentPlatformId': 'KR',
#             'matchHistoryUri': '/v1/stats/player_history/KR/2966898',
#             'platformId': 'KR',
#             'profileIcon': 4050,
#             'summonerId': 'GK3HYYyUSTSeclB3RCqD81QXQ_ovOL2O2hJGAMuQtPhRpw',
#             'summonerName': '깜짝상자 속 춘배'}}
# {'participantId': 5,
#  'player': {'accountId': 'xs8wr7y5NVN4F5Lo0oYD1WfO-LgFsn9otSL4AY8G9-VA5-MdWbrX9XGn',
#             'currentAccountId': 'xs8wr7y5NVN4F5Lo0oYD1WfO-LgFsn9otSL4AY8G9-VA5-MdWbrX9XGn',
#             'currentPlatformId': 'KR',
#             'matchHistoryUri': '/v1/stats/player_history/KR/2172365979037248',
#             'platformId': 'KR',
#             'profileIcon': 3544,
#             'summonerId': 'qLoecuYWXqIvMrJGVjga6itaZG_wOHhZ9imEEZKxv6hylrU',
#             'summonerName': '깜작상자 속 배춘'}}
# {'participantId': 6,
#  'player': {'accountId': 'QfdZg2xrmW0h1vOwYBoWtf-PFZoSV45apJZftwToEDX5vcg',
#             'currentAccountId': 'QfdZg2xrmW0h1vOwYBoWtf-PFZoSV45apJZftwToEDX5vcg',
#             'currentPlatformId': 'KR',
#             'matchHistoryUri': '/v1/stats/player_history/KR/210388611',
#             'platformId': 'KR',
#             'profileIcon': 3018,
#             'summonerId': 'DgqFfWL_mEG2LE187TofGnOK5v2f75MibpYQsJd5U8BQNss',
#             'summonerName': '막판하고잠자쟝'}}
# {'participantId': 7,
#  'player': {'accountId': '62D2zpW9aHU1nObms6UB5XtDFLLllBqDOP0FPXriJ065LnXOCPkTGNUD',
#             'currentAccountId': '62D2zpW9aHU1nObms6UB5XtDFLLllBqDOP0FPXriJ065LnXOCPkTGNUD',
#             'currentPlatformId': 'KR',
#             'matchHistoryUri': '/v1/stats/player_history/KR/2182213137558976',
#             'platformId': 'KR',
#             'profileIcon': 3546,
#             'summonerId': '-vSAvUFoGMuSdAYQlvkXqi353qTqrjDNoXvclZIaOpwBL1E',
#             'summonerName': 'marwin'}}
# {'participantId': 8,
#  'player': {'accountId': 'uRY9IjFuHod4RV41hX8Lykdy9c_2ePvRP9-vpt_DWwjJ',
#             'currentAccountId': 'uRY9IjFuHod4RV41hX8Lykdy9c_2ePvRP9-vpt_DWwjJ',
#             'currentPlatformId': 'KR',
#             'matchHistoryUri': '/v1/stats/player_history/KR/7289646',
#             'platformId': 'KR',
#             'profileIcon': 4027,
#             'summonerId': '0FxIsgB4xYhLq9dQhfIqgUm_XMzFggSmug8kmEqA44ectGE',
#             'summonerName': '한 림 법 학 원'}}
# {'participantId': 9,
#  'player': {'accountId': 'asIlMn3Fbr0zFBKeT_GmREM9oXZBtXrSyUauc7kfWjdnIPs',
#             'currentAccountId': 'asIlMn3Fbr0zFBKeT_GmREM9oXZBtXrSyUauc7kfWjdnIPs',
#             'currentPlatformId': 'KR',
#             'matchHistoryUri': '/v1/stats/player_history/KR/204866335',
#             'platformId': 'KR',
#             'profileIcon': 4022,
#             'summonerId': '08MeAXu_5m1igRzodd_JkKbsAxCM9XOCt6AZob3L7LSKSIQ',
#             'summonerName': '공자누님'}}
# {'participantId': 10,
#  'player': {'accountId': 'HWmLOlQHyRExlDViD6YPfzkHyBzhAy_rb80XfB7PUwPwszs',
#             'currentAccountId': 'HWmLOlQHyRExlDViD6YPfzkHyBzhAy_rb80XfB7PUwPwszs',
#             'currentPlatformId': 'KR',
#             'matchHistoryUri': '/v1/stats/player_history/KR/202921200',
#             'platformId': 'KR',
#             'profileIcon': 787,
#             'summonerId': 'jr7NPMGCaHEoiaa0cCvXep9N7x4uXSaepAxM9PQ8_RepAmE',
#             'summonerName': '4700원입니다'}}

# %%
teamId_dict = {100 : "Red", 200: "Blue"}

champion_dict = get_champion_json()


for i in range(10):
    championId = data['participants'][i]['championId']
    print(champion_dict[str(championId)])
    teamId = data['participants'][i]['teamId']
    print(teamId_dict[teamId])
# Out:
# 아리
# Red
# 케이틀린
# Red
# 티모
# Red
# 베이가
# Red
# 마스터 이
# Red
# 말파이트
# Blue
# 초가스
# Blue
# 리 신
# Blue
# 야스오
# Blue
# 조이
# Blue
